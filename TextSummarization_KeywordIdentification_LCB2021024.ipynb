# %% [markdown]
# Text Summarization
# ==================
#
#
# Shows how to summarize text by extracting the most important sentences from it.
#
# This module automatically summarizes the given text by extracting one or more important sentences from the text. Similarly, it can also extract keywords.
#
# This summarizer is based on the "TextRank" algorithm.
#
#
#
# **Extractive summarization** involves selecting and combining crucial sentences, phrases, or words from an original text to create a shorter version. Generally, the extracted information remains unchanged from the input. (Relative order of sentences may change but every sentence is taken from input)

# %%
from pprint import pprint as print
from gensim.summarization import summarize

# %% [markdown]
# `gensim` is a robust, efficient open-source python library which is designed for Natural Language Processing(NLP), topic modeling, similarity retrieval using corpora and document indexing etc..
#
# `gensim.summarization.summarize` this function provided by the `gensim` library,
#
#
# This function is important for summarizing text. It uses a modified version of the TextRank algorithm to select the important sentences from the input text and create a summary that contain the most important information.
#
# **TextRank** is an unsupervised, graph-based ranking algorithm used for Natural Language Processing tasks, like extracting keywords from text or generating summaries.Its works by assuming the text like a graph with nodes as words or sentences and the edges indicate how the nodes relate to each other.TextRank uses PageRank to determine the most important nodes which are used to generate summaries or highlight important sentences in texts.

# %% [markdown]
# Let's consider this example for better understanding.

# %% [markdown]
# Extractive summarization is a text summarization technique based on identifying and separating the primary sentences or phrases in the source text to create summary. The extractive summarization systems employ statistical algorithms and linguistic analysis to assess word frequency, sentence position, and keyword occurrence to gauge the importance of each type of textual input. The prioritized sentences are then placed together to develop a brief, information summary. The primary benefit of extractive summarization is its simplicity and the ability for computational deployment. Additionally, the process is relatively straight forward, as the summary is based on the pre-existing text and its extraction. However, in the operational mode, the summaries may lose interpersonal aspects and lack a wholistic context."

# %%
# text = (
#     "Extractive summarization is a text summarization technique based on identifying and separating the primary sentences or phrases in the source text to create summary. The extractive summarization systems employ statistical algorithms and linguistic analysis to assess word frequency, sentence position, and keyword occurrence to gauge the importance of each type of textual input. The prioritized sentences are then placed together to develop a brief, information summary. The primary benefit of extractive summarization is its simplicity and the ability for computational deployment. Additionally, the process is relatively straight forward, as the summary is based on the pre-existing text and its extraction. However, in the operational mode, the summaries may lose interpersonal aspects and lack a wholistic context."
# )
text = input("Enter text: ")
print(text)
# Out:
# ('Extractive summarization is a text summarization technique based on '
#  'identifying and separating the primary sentences or phrases in the source '
#  'text to create summary. The extractive summarization systems employ '
#  'statistical algorithms and linguistic analysis to assess word frequency, '
#  'sentence position, and keyword occurrence to gauge the importance of each '
#  'type of textual input. The prioritized sentences are then placed together to '
#  'develop a brief, information summary. The primary benefit of extractive '
#  'summarization is its simplicity and the ability for computational '
#  'deployment. Additionally, the process is relatively straight forward, as the '
#  'summary is based on the pre-existing text and its extraction. However, in '
#  'the operational mode, the summaries may lose interpersonal aspects and lack '
#  'a wholistic context')

# %% [markdown]
# When we pass the string data(input text) as an input to the summarize function, the function will process the data and generate a summary based on the input text.

# %%
print(summarize(text))
# Out:
# ('Extractive summarization is a text summarization technique based on '
#  'identifying and separating the primary sentences or phrases in the source '
#  'text to create summary.')

# %% [markdown]
# As we are implementing Extractive summarization, the output generated is not created externally, it just the part of the input text which is most significant among all the sentences.

# %%
print(summarize(text, ratio=0.6))
# Out:
# ('Extractive summarization is a text summarization technique based on '
#  'identifying and separating the primary sentences or phrases in the source '
#  'text to create summary.\n'
#  'The primary benefit of extractive summarization is its simplicity and the '
#  'ability for computational deployment.\n'
#  'Additionally, the process is relatively straight forward, as the summary is '
#  'based on the pre-existing text and its extraction.')

# %%
print(summarize(text, split=True))
# Out:
# ['Extractive summarization is a text summarization technique based on '
#  'identifying and separating the primary sentences or phrases in the source '
#  'text to create summary.']

# %%
print(summarize(text, word_count=50))
# Out:
# ('Extractive summarization is a text summarization technique based on '
#  'identifying and separating the primary sentences or phrases in the source '
#  'text to create summary.\n'
#  'Additionally, the process is relatively straight forward, as the summary is '
#  'based on the pre-existing text and its extraction.')

# %% [markdown]
# Here the summarize function has 2 attributes for each call, i.e; the input text and ratio, split, wordcount respectively. So, each attribute has its own function.
#
# *ratio* controls the length of summary as a fraction of input text.
#
# *split* when set to True, returns the summary as a list of sentences instead of single sentence/string.
#
# *word_count* specifies the maximum number of words in the summary.

# %% [markdown]
# KeyWord Identification
# ==================
#
# As mentioned earlier, this module also supports keyword extraction. Keyword extraction works in the same way as summary generation (i.e. sentence extraction), in that the algorithm tries to find words that are important or seem to be representative of the text as a whole.

# %%
from gensim.summarization import keywords

# %% [markdown]
# `gensim.summarization.keywords` function is used for identification and extracting the words/phrases from the text data.
#
# The gensim keywords module uses Natural Language Processing techniques, like term frequency-inverse document frequency (TF-IDF), to find the most important keywords in a given text.

# %%
print(keywords(text))
# Out:
# ('sentences\n'
#  'sentence\n'
#  'summarization\n'
#  'text\n'
#  'deployment\n'
#  'straight\n'
#  'interpersonal\n'
#  'summary\n'
#  'summaries\n'
#  'information')

# %%
print(keywords(text,  lemmatize=True))
# Out:
# ('sentence\n'
#  'summarization\n'
#  'text\n'
#  'straight\n'
#  'deployment\n'
#  'interpersonal\n'
#  'information\n'
#  'summaries')

# %%
print(keywords(text, split=True))
# Out:
# ['sentences',
#  'sentence',
#  'summarization',
#  'text',
#  'straight',
#  'deployment',
#  'interpersonal',
#  'summary',
#  'summaries',
#  'information']

# %%
print(keywords(text, ratio=0.4))
# Out:
# ('summarization\n'
#  'primary sentences\n'
#  'frequency sentence\n'
#  'text\n'
#  'deployment\n'
#  'interpersonal\n'
#  'straight\n'
#  'information\n'
#  'summary\n'
#  'summaries\n'
#  'word\n'
#  'technique\n'
#  'systems employ statistical\n'
#  'wholistic')

# %% [markdown]
# Similarly, in keyword extraction, there are two parameters: input text and lemmatize, split, ratio are also important parameters.
#
# *lemmatize* when set to True, this parameter lemmatizes the keywords.(Lemmatization reduces the given word into its root word)
#
# *split* when set to True, returns the keywords as a list.
#
# *ratio* specifies the number of keywords relative to the number of words in input text.

# %% [markdown]
# Lets take a larger example, **Text file** as input data

# %%
with open('avatar.txt', 'r') as file:
    text1 = file.read()

print(text1)
# Out:
# ("In 2154, humans have depleted Earth's natural resources, leading to a severe "
#  'energy crisis. The Resources Development Administration (RDA) mines a '
#  'valuable mineral Unobtanium on Pandora, a densely forested habitable moon '
#  'orbiting Polyphemus, a fictional gas giant in the Alpha Centauri star '
#  'system. Pandora, whose atmosphere is poisonous to humans, is inhabited by '
#  "the Na'Vi, a species of 10-foot tall (3.0 m), blue-skinned, sapient "
#  'humanoids that live in harmony with nature and worship a mother goddess '
#  'named Eywa. It takes 6 years to get from Earth to Pandora in cryogenic '
#  'sleep.\n'
#  '\n'
#  "To explore Pandora's biosphere, scientists use Na'Vi-human hybrids (grown "
#  'from human + native DNA) called "avatars", operated by genetically matched '
#  'humans. Jake Sully (Sam Worthington), a paraplegic former Marine, replaces '
#  'his deceased identical twin brother as an operator of one. Jake was leading '
#  'a purposeless life on Earth and was contacted by RDA when his brother died. '
#  'his brother represented a significant investment by RDA, since the avatars '
#  'are linked to the human DNA/genome. Since Jake is a twin, he has the same '
#  'exact DNA as his brother and can take his place in the Avatar program. Dr. '
#  'Grace Augustine (Sigourney Weaver), head of the Avatar Program, considers '
#  'Sully an inadequate replacement (as she considers Jake a mere Jarhead) but '
#  "accepts his assignment as a bodyguard for excursions deep into Na'Vi "
#  'territory.\n'
#  '\n'
#  'Tracy (Michelle Rodriguez) is the pilot assigned to Grace and her team of '
#  "Na'Vis. While escorting the avatars of Grace and fellow scientist Dr. Norm "
#  "Spellman (Joel David Moore), Jake's avatar is attacked by a Thanator (while "
#  'they were visiting the school that Grace was operating to teach the '
#  'Omaticaya. She also does test on tree roots and is developing a theory that '
#  'all living things on the planet are somehow attached and connected to each '
#  'other) and flees into the forest, where he is rescued by Neytiri (Zoe '
#  "Saldana), a female Na'Vi. Witnessing an auspicious sign (Seeds of the sacred "
#  'tree land on Jake, covering him. Something she later calls Eywa), she takes '
#  "him to her clan. The Na'Vi respect all living things and Neytiri is angry "
#  "because to save Jake she had to kill many native species. Neytiri's mother "
#  "Mo'At (CCH Pounder), the clan's spiritual leader, orders her daughter to "
#  'initiate Jake into their society. Grace and Tracy return to base camp, as '
#  'they are not allowed to run night ops as per protocol. The Omaticaya (the '
#  "Na'Vi clan has its HQ in the Hometree)\n"
#  '\n'
#  "Colonel Miles Quaritch (Stephen Lang), head of RDA's private security force, "
#  'promises Jake that the company will restore his legs if he gathers '
#  "information about the Na'Vi and the clan's gathering place, a giant tree "
#  'called Hometree, which stands above the richest deposit of Unobtanium in the '
#  "area. Jake has 3 months to convince the Na'Vi to move as that's when the "
#  'bulldozers get to the tree. Jake learns that Neytiri and her sister Slywanin '
#  "studied at Grace's school. Sylwanin is dead. When Grace learns of Jake's "
#  'work for Miles (she sees him explaining the inner structure of the Hometree '
#  'to Miles and Parker), she transfers herself, Jake, and Norm to an outpost. '
#  'Over the following three months, Jake and Neytiri fall in love as Jake grows '
#  'to sympathize with the natives. Neytiri also teaches Jake about Eywa, the '
#  'network of energy that flows through all living things. Grace also reveals '
#  'that one day the Omaticaya destroyed a bulldozer and hid inside her school. '
#  "Miles's troopers attacked them and Sylwanin died. The Na'Vi never returned. "
#  "They wanted Grace to protect the Na'Vi.\n"
#  '\n'
#  'After Jake is initiated into the tribe (he even captures a banshee/Ikran (a '
#  'flying predator kind of creature), after Neytiri deems him ready to be a '
#  'warrior. She even takes Jake to the tree of souls, their most sacred site), '
#  'he and Neytiri choose each other as mates. Jake and Neytiri escape an attack '
#  'from Toruk, the biggest banshee in the sky. Rider of the Toruk is called '
#  'Toruk Macto. Soon afterward, Jake reveals his change of allegiance when he '
#  "attempts to disable a bulldozer that threatens to destroy a sacred Na'Vi "
#  "site. When Quaritch shows a video recording of Jake's attack on the "
#  'bulldozer to Administrator Parker Selfridge (Giovanni Ribisi), and another '
#  "in which Jake admits that the Na'Vi will never abandon Hometree, Selfridge "
#  'orders Hometree destroyed (this was after the Omaticaya retaliated and '
#  'destroyed the bulldozers and killed 6 humans in the process. Grace thinks '
#  'the bulldozers were specifically sent to evoke a response and use that as an '
#  'excuse for war)\n'
#  '\n'
#  "Despite Grace's argument that destroying Hometree could damage the "
#  'biological neural network native to Pandora, Selfridge gives Jake and Grace '
#  "one hour to convince the Na'Vi to evacuate before commencing the attack. "
#  "Jake confesses to the Na'Vi that he was a spy, and they take him and Grace "
#  "captive. Quaritch's men destroy Hometree, killing Neytiri's father (the clan "
#  "chief) and many others. Mo'At frees Jake and Grace, but they are detached "
#  "from their avatars and imprisoned by Quaritch's forces. Pilot Trudy Chacón, "
#  "disgusted by Quaritch's brutality, frees Jake, Grace, and Norm, and airlifts "
#  "them to Grace's outpost, but Grace is shot by Quaritch during the escape. "
#  'Trudy takes the mobile station and hides it near the tree of souls where '
#  'Miles cannot find it as the flux vortex scrambles all radars.\n'
#  '\n'
#  "To regain the Na'Vi's trust, Jake attacks and connects his mind to that of "
#  "Toruk, a dragon-like predator feared and honored by the Na'Vi. Jake finds "
#  'the refugees at the sacred Tree of Souls (the Omaticaya are forced to take '
#  'him seriously due to the power and symbolism of the Toruk) and pleads with '
#  "Mo'At to heal Grace. The clan attempts to transfer Grace from her human body "
#  'into her avatar with the aid of the Tree of Souls, but she dies before the '
#  "process can be completed. Supported by the new chief Tsu'Tey (Laz Alonso), "
#  'Jake unites the clan and tells them to gather all of the clans to battle the '
#  'RDA. Quaritch organizes a preemptive strike against the Tree of Souls, '
#  'believing that its destruction will demoralize the natives. On the eve of '
#  'battle, Jake prays to Eywa, via a neural connection with the Tree of Souls, '
#  "to intercede on behalf of the Na'Vi.\n"
#  '\n'
#  "During the subsequent battle, the Na'Vi suffer heavy casualties, including "
#  "Tsu'Tey and Trudy, but are rescued when Pandoran wildlife unexpectedly join "
#  "the attack and overwhelm the humans, which Neytiri interprets as Eywa's "
#  "answer to Jake's prayer. Jake destroys a makeshift bomber before it can "
#  'reach the Tree of Souls; Quaritch, wearing an AMP suit, escapes from his own '
#  "damaged aircraft and breaks open the avatar link unit containing Jake's "
#  "human body, exposing it to Pandora's poisonous atmosphere. Quaritch prepares "
#  "to slit the throat of Jake's avatar, but Neytiri kills Quaritch and saves "
#  'Jake from suffocation, seeing his human form for the first time.\n'
#  '\n'
#  'With the exceptions of Jake, Norm and a select few others, all humans are '
#  'expelled from Pandora and sent back to Earth. Jake is permanently '
#  'transferred into his avatar with the aid of the Tree of Souls.')

# %%
print(summarize(text1))
# Out:
# ("To explore Pandora's biosphere, scientists use Na'Vi-human hybrids (grown "
#  'from human + native DNA) called "avatars", operated by genetically matched '
#  'humans.\n'
#  'Tracy (Michelle Rodriguez) is the pilot assigned to Grace and her team of '
#  "Na'Vis. While escorting the avatars of Grace and fellow scientist Dr. Norm "
#  "Spellman (Joel David Moore), Jake's avatar is attacked by a Thanator (while "
#  'they were visiting the school that Grace was operating to teach the '
#  'Omaticaya.\n'
#  "Colonel Miles Quaritch (Stephen Lang), head of RDA's private security force, "
#  'promises Jake that the company will restore his legs if he gathers '
#  "information about the Na'Vi and the clan's gathering place, a giant tree "
#  'called Hometree, which stands above the richest deposit of Unobtanium in the '
#  'area.\n'
#  'She even takes Jake to the tree of souls, their most sacred site), he and '
#  'Neytiri choose each other as mates.\n'
#  "When Quaritch shows a video recording of Jake's attack on the bulldozer to "
#  'Administrator Parker Selfridge (Giovanni Ribisi), and another in which Jake '
#  "admits that the Na'Vi will never abandon Hometree, Selfridge orders Hometree "
#  'destroyed (this was after the Omaticaya retaliated and destroyed the '
#  'bulldozers and killed 6 humans in the process.\n'
#  "Quaritch's men destroy Hometree, killing Neytiri's father (the clan chief) "
#  'and many others.\n'
#  "To regain the Na'Vi's trust, Jake attacks and connects his mind to that of "
#  "Toruk, a dragon-like predator feared and honored by the Na'Vi. Jake finds "
#  'the refugees at the sacred Tree of Souls (the Omaticaya are forced to take '
#  'him seriously due to the power and symbolism of the Toruk) and pleads with '
#  "Mo'At to heal Grace.\n"
#  'The clan attempts to transfer Grace from her human body into her avatar with '
#  'the aid of the Tree of Souls, but she dies before the process can be '
#  'completed.\n'
#  'Jake destroys a makeshift bomber before it can reach the Tree of Souls; '
#  'Quaritch, wearing an AMP suit, escapes from his own damaged aircraft and '
#  "breaks open the avatar link unit containing Jake's human body, exposing it "
#  "to Pandora's poisonous atmosphere.\n"
#  "Quaritch prepares to slit the throat of Jake's avatar, but Neytiri kills "
#  'Quaritch and saves Jake from suffocation, seeing his human form for the '
#  'first time.')

# %%
print(summarize(text1, ratio=0.7))
# Out:
# ("Pandora, whose atmosphere is poisonous to humans, is inhabited by the Na'Vi, "
#  'a species of 10-foot tall (3.0 m), blue-skinned, sapient humanoids that live '
#  'in harmony with nature and worship a mother goddess named Eywa.\n'
#  "To explore Pandora's biosphere, scientists use Na'Vi-human hybrids (grown "
#  'from human + native DNA) called "avatars", operated by genetically matched '
#  'humans.\n'
#  'Jake was leading a purposeless life on Earth and was contacted by RDA when '
#  'his brother died.\n'
#  'his brother represented a significant investment by RDA, since the avatars '
#  'are linked to the human DNA/genome.\n'
#  'Since Jake is a twin, he has the same exact DNA as his brother and can take '
#  'his place in the Avatar program.\n'
#  'Dr. Grace Augustine (Sigourney Weaver), head of the Avatar Program, '
#  'considers Sully an inadequate replacement (as she considers Jake a mere '
#  'Jarhead) but accepts his assignment as a bodyguard for excursions deep into '
#  "Na'Vi territory.\n"
#  'Tracy (Michelle Rodriguez) is the pilot assigned to Grace and her team of '
#  "Na'Vis. While escorting the avatars of Grace and fellow scientist Dr. Norm "
#  "Spellman (Joel David Moore), Jake's avatar is attacked by a Thanator (while "
#  'they were visiting the school that Grace was operating to teach the '
#  'Omaticaya.\n'
#  'She also does test on tree roots and is developing a theory that all living '
#  'things on the planet are somehow attached and connected to each other) and '
#  'flees into the forest, where he is rescued by Neytiri (Zoe Saldana), a '
#  "female Na'Vi. Witnessing an auspicious sign (Seeds of the sacred tree land "
#  'on Jake, covering him.\n'
#  'Something she later calls Eywa), she takes him to her clan.\n'
#  "The Na'Vi respect all living things and Neytiri is angry because to save "
#  'Jake she had to kill many native species.\n'
#  "Neytiri's mother Mo'At (CCH Pounder), the clan's spiritual leader, orders "
#  'her daughter to initiate Jake into their society.\n'
#  'Grace and Tracy return to base camp, as they are not allowed to run night '
#  'ops as per protocol.\n'
#  "Colonel Miles Quaritch (Stephen Lang), head of RDA's private security force, "
#  'promises Jake that the company will restore his legs if he gathers '
#  "information about the Na'Vi and the clan's gathering place, a giant tree "
#  'called Hometree, which stands above the richest deposit of Unobtanium in the '
#  'area.\n'
#  "Jake learns that Neytiri and her sister Slywanin studied at Grace's school.\n"
#  "When Grace learns of Jake's work for Miles (she sees him explaining the "
#  'inner structure of the Hometree to Miles and Parker), she transfers herself, '
#  'Jake, and Norm to an outpost.\n'
#  'Over the following three months, Jake and Neytiri fall in love as Jake grows '
#  'to sympathize with the natives.\n'
#  'Neytiri also teaches Jake about Eywa, the network of energy that flows '
#  'through all living things.\n'
#  'Grace also reveals that one day the Omaticaya destroyed a bulldozer and hid '
#  'inside her school.\n'
#  "Miles's troopers attacked them and Sylwanin died.\n"
#  'She even takes Jake to the tree of souls, their most sacred site), he and '
#  'Neytiri choose each other as mates.\n'
#  'Jake and Neytiri escape an attack from Toruk, the biggest banshee in the '
#  'sky.\n'
#  "When Quaritch shows a video recording of Jake's attack on the bulldozer to "
#  'Administrator Parker Selfridge (Giovanni Ribisi), and another in which Jake '
#  "admits that the Na'Vi will never abandon Hometree, Selfridge orders Hometree "
#  'destroyed (this was after the Omaticaya retaliated and destroyed the '
#  'bulldozers and killed 6 humans in the process.\n'
#  "Despite Grace's argument that destroying Hometree could damage the "
#  'biological neural network native to Pandora, Selfridge gives Jake and Grace '
#  "one hour to convince the Na'Vi to evacuate before commencing the attack.\n"
#  "Quaritch's men destroy Hometree, killing Neytiri's father (the clan chief) "
#  'and many others.\n'
#  "Mo'At frees Jake and Grace, but they are detached from their avatars and "
#  "imprisoned by Quaritch's forces.\n"
#  'Trudy takes the mobile station and hides it near the tree of souls where '
#  'Miles cannot find it as the flux vortex scrambles all radars.\n'
#  "To regain the Na'Vi's trust, Jake attacks and connects his mind to that of "
#  "Toruk, a dragon-like predator feared and honored by the Na'Vi. Jake finds "
#  'the refugees at the sacred Tree of Souls (the Omaticaya are forced to take '
#  'him seriously due to the power and symbolism of the Toruk) and pleads with '
#  "Mo'At to heal Grace.\n"
#  'The clan attempts to transfer Grace from her human body into her avatar with '
#  'the aid of the Tree of Souls, but she dies before the process can be '
#  'completed.\n'
#  'Quaritch organizes a preemptive strike against the Tree of Souls, believing '
#  'that its destruction will demoralize the natives.\n'
#  'On the eve of battle, Jake prays to Eywa, via a neural connection with the '
#  "Tree of Souls, to intercede on behalf of the Na'Vi.\n"
#  "During the subsequent battle, the Na'Vi suffer heavy casualties, including "
#  "Tsu'Tey and Trudy, but are rescued when Pandoran wildlife unexpectedly join "
#  "the attack and overwhelm the humans, which Neytiri interprets as Eywa's "
#  "answer to Jake's prayer.\n"
#  'Jake destroys a makeshift bomber before it can reach the Tree of Souls; '
#  'Quaritch, wearing an AMP suit, escapes from his own damaged aircraft and '
#  "breaks open the avatar link unit containing Jake's human body, exposing it "
#  "to Pandora's poisonous atmosphere.\n"
#  "Quaritch prepares to slit the throat of Jake's avatar, but Neytiri kills "
#  'Quaritch and saves Jake from suffocation, seeing his human form for the '
#  'first time.\n'
#  'With the exceptions of Jake, Norm and a select few others, all humans are '
#  'expelled from Pandora and sent back to Earth.\n'
#  'Jake is permanently transferred into his avatar with the aid of the Tree of '
#  'Souls.')

# %%
print(summarize(text1, split=True))
# Out:
# ["To explore Pandora's biosphere, scientists use Na'Vi-human hybrids (grown "
#  'from human + native DNA) called "avatars", operated by genetically matched '
#  'humans.',
#  'Tracy (Michelle Rodriguez) is the pilot assigned to Grace and her team of '
#  "Na'Vis. While escorting the avatars of Grace and fellow scientist Dr. Norm "
#  "Spellman (Joel David Moore), Jake's avatar is attacked by a Thanator (while "
#  'they were visiting the school that Grace was operating to teach the '
#  'Omaticaya.',
#  "Colonel Miles Quaritch (Stephen Lang), head of RDA's private security force, "
#  'promises Jake that the company will restore his legs if he gathers '
#  "information about the Na'Vi and the clan's gathering place, a giant tree "
#  'called Hometree, which stands above the richest deposit of Unobtanium in the '
#  'area.',
#  'She even takes Jake to the tree of souls, their most sacred site), he and '
#  'Neytiri choose each other as mates.',
#  "When Quaritch shows a video recording of Jake's attack on the bulldozer to "
#  'Administrator Parker Selfridge (Giovanni Ribisi), and another in which Jake '
#  "admits that the Na'Vi will never abandon Hometree, Selfridge orders Hometree "
#  'destroyed (this was after the Omaticaya retaliated and destroyed the '
#  'bulldozers and killed 6 humans in the process.',
#  "Quaritch's men destroy Hometree, killing Neytiri's father (the clan chief) "
#  'and many others.',
#  "To regain the Na'Vi's trust, Jake attacks and connects his mind to that of "
#  "Toruk, a dragon-like predator feared and honored by the Na'Vi. Jake finds "
#  'the refugees at the sacred Tree of Souls (the Omaticaya are forced to take '
#  'him seriously due to the power and symbolism of the Toruk) and pleads with '
#  "Mo'At to heal Grace.",
#  'The clan attempts to transfer Grace from her human body into her avatar with '
#  'the aid of the Tree of Souls, but she dies before the process can be '
#  'completed.',
#  'Jake destroys a makeshift bomber before it can reach the Tree of Souls; '
#  'Quaritch, wearing an AMP suit, escapes from his own damaged aircraft and '
#  "breaks open the avatar link unit containing Jake's human body, exposing it "
#  "to Pandora's poisonous atmosphere.",
#  "Quaritch prepares to slit the throat of Jake's avatar, but Neytiri kills "
#  'Quaritch and saves Jake from suffocation, seeing his human form for the '
#  'first time.']

# %%
print(summarize(text1, word_count=100))
# Out:
# ("Colonel Miles Quaritch (Stephen Lang), head of RDA's private security force, "
#  'promises Jake that the company will restore his legs if he gathers '
#  "information about the Na'Vi and the clan's gathering place, a giant tree "
#  'called Hometree, which stands above the richest deposit of Unobtanium in the '
#  'area.\n'
#  'The clan attempts to transfer Grace from her human body into her avatar with '
#  'the aid of the Tree of Souls, but she dies before the process can be '
#  'completed.\n'
#  'Jake destroys a makeshift bomber before it can reach the Tree of Souls; '
#  'Quaritch, wearing an AMP suit, escapes from his own damaged aircraft and '
#  "breaks open the avatar link unit containing Jake's human body, exposing it "
#  "to Pandora's poisonous atmosphere.")

# %%
print(keywords(text1))
# Out:
# ('jake\n'
#  'grace\n'
#  'quaritch\n'
#  'neytiri\n'
#  'humans\n'
#  'human\n'
#  'calls\n'
#  'hometree\n'
#  'tree\n'
#  'selfridge\n'
#  'predator\n'
#  'dna called\n'
#  'scientists\n'
#  'scientist\n'
#  'native\n'
#  'natives\n'
#  'tracy\n'
#  'trudy\n'
#  'destroyed\n'
#  'destroy\n'
#  'destroying\n'
#  'destroys\n'
#  'avatars\n'
#  'avatar\n'
#  'resources\n'
#  'neural\n'
#  'brother\n'
#  'chief\n'
#  'replaces\n'
#  'replacement\n'
#  'energy\n'
#  'slywanin\n'
#  'centauri\n'
#  'mineral\n'
#  'vortex\n'
#  'night\n'
#  'sign\n'
#  'banshee\n'
#  'gathers\n'
#  'gathering\n'
#  'gather\n'
#  'kill\n'
#  'killed\n'
#  'killing\n'
#  'kills\n'
#  'tsu\n'
#  'pilot\n'
#  'force\n'
#  'forces\n'
#  'forced\n'
#  'wildlife unexpectedly\n'
#  'sapient\n'
#  'rda\n'
#  'administration\n'
#  'administrator\n'
#  'takes\n'
#  'escape\n'
#  'escapes\n'
#  'michelle\n'
#  'sully\n'
#  'miles\n'
#  'forest\n'
#  'orders\n'
#  'forested habitable moon orbiting\n'
#  'considers\n'
#  'unites\n'
#  'unit')

# %%
print(keywords(text1, lemmatize=True))
# Out:
# ('jake\n'
#  'grace\n'
#  'quaritch\n'
#  'neytiri\n'
#  'human\n'
#  'calls\n'
#  'hometree\n'
#  'tree\n'
#  'selfridge\n'
#  'predator\n'
#  'scientist\n'
#  'dna\n'
#  'natives\n'
#  'tracy\n'
#  'trudy\n'
#  'destroys\n'
#  'avatar\n'
#  'resources\n'
#  'neural\n'
#  'brother\n'
#  'chief\n'
#  'banshee\n'
#  'vortex\n'
#  'night\n'
#  'slywanin\n'
#  'centauri\n'
#  'mineral\n'
#  'replacement\n'
#  'sign\n'
#  'gather\n'
#  'energy\n'
#  'kills\n'
#  'tsu\n'
#  'pilot\n'
#  'forced\n'
#  'wildlife unexpectedly\n'
#  'sapient\n'
#  'rda\n'
#  'administrator\n'
#  'takes\n'
#  'escapes\n'
#  'michelle\n'
#  'sully\n'
#  'miles\n'
#  'forest\n'
#  'orders\n'
#  'considers\n'
#  'habitable moon orbiting\n'
#  'unit')

# %%
print(keywords(text1, ratio=0.05))
# Out:
# ('jake\n'
#  'grace\n'
#  'quaritch\n'
#  'neytiri\n'
#  'humans\n'
#  'human\n'
#  'calls\n'
#  'hometree\n'
#  'tree\n'
#  'selfridge\n'
#  'predator\n'
#  'dna called\n'
#  'scientists\n'
#  'scientist\n'
#  'native\n'
#  'natives')

# %%
print(keywords(text1, split=True))
# Out:
# ['jake',
#  'grace',
#  'quaritch',
#  'neytiri',
#  'humans',
#  'human',
#  'calls',
#  'hometree',
#  'tree',
#  'selfridge',
#  'predator',
#  'dna called',
#  'scientists',
#  'scientist',
#  'native',
#  'natives',
#  'tracy',
#  'trudy',
#  'destroyed',
#  'destroy',
#  'destroying',
#  'destroys',
#  'avatars',
#  'avatar',
#  'resources',
#  'neural',
#  'brother',
#  'chief',
#  'energy',
#  'banshee',
#  'slywanin',
#  'sign',
#  'mineral',
#  'gathers',
#  'gathering',
#  'gather',
#  'vortex',
#  'night',
#  'replaces',
#  'replacement',
#  'centauri',
#  'kill',
#  'killed',
#  'killing',
#  'kills',
#  'tsu',
#  'pilot',
#  'force',
#  'forces',
#  'forced',
#  'wildlife unexpectedly',
#  'sapient',
#  'rda',
#  'administration',
#  'administrator',
#  'takes',
#  'escape',
#  'escapes',
#  'michelle',
#  'sully',
#  'miles',
#  'forest',
#  'orders',
#  'forested habitable moon orbiting',
#  'considers',
#  'unites',
#  'unit']

# %% [markdown]
# Now we will look into **PDF** files as input data

# %%
import PyPDF2

# %% [markdown]
# `PyPDF2` is a python library, which is used for reading and manuplating the PDF files.
# It has many functionalities in handling PDF files.
# *  Reading PDF files: Read and extract text, and content from PDF files.
# *  Merging PDF files: Combining multiple PDF files into single file.
# *  Splitting PDF files: Split PDF file into multiples files.
# *  Encrypting and Decrypting PDFs: Add passwords to PDF files for security.
# * Rotating Pages: Rotate pages in PDF files.

# %%
reader = PyPDF2.PdfReader('economics_chap1.pdf')

fulltext=""
for pgnum in range(len(reader.pages)):
    pagecontent=reader.pages[pgnum].extract_text()
    fulltext+=pagecontent

print(fulltext)
# Out:
# ('Macroeconomics\n'
#  '1\n'
#  'Macroeconomics\n'
#  'MACRO → Greek word → Makros → Large/aggregate\n'
#  'Study of macroeconomics as a separate branch is a recent origin. It started '
#  'after the  \n'
#  'classification of economics as microeconomics and macroeconomics by Prof. '
#  'Ragnar  \n'
#  'Frisch in 1933.\n'
#  'Historical Review of Macroeconomy\n'
#  '16th and 17th Century - Advisers of English merchantilist groups '
#  'advocated  \n'
#  'policies to the government based on macroeconomic approach\n'
#  '18th Century - Physiocrats - the French thinkers tried to analyse the '
#  'concept of  \n'
#  'national income and wealth\n'
#  'Classical Economic Theories - Theories of Adam Smith and J.S. Mill  \n'
#  'discussed the determination of national income and wealth and division of  \n'
#  'national income into total wages, total rent and total profit. However , '
#  'their macro  \n'
#  'analysis was combined with micro analysis.\n'
#  'Neo-classical Economists - The increasing importance of macroeconomists  \n'
#  'was halted by neo-classical economists - Alfred Marshall and Pigou. There, '
#  'the  \n'
#  'microanalysis ruled the world of economics till the Great Depression of '
#  '1930s.Macroeconomics\n'
#  '2Post-Great-Depression Period - Revolutionary changes took place in  \n'
#  'economic thinking. Lord John Keynes published his book “General Theory of  \n'
#  'Employment, Interest and Money” in 1936. Apart from Keynes, Malthus, Karl  \n'
#  'Marx and Fischer have also contributed towards development of  \n'
#  'macroeconomics but the main credit goes to Keynes.\n'
#  'Post-Keynesian Economists - After Keynes, Harrod and Domar used  \n'
#  'macroanalysis to develop Theory of Growth.\n'
#  'Government Budget\n'
#  'Budget is derived from French word ‘Bougetts’  which means ‘small bag’.\n'
#  'For the first time, in 1733, the British Finance Minister Sir Robert W '
#  'alpole presented  \n'
#  'the budget in the British Parliament.\n'
#  'In India, during British period, James Wilson presented India’ s first '
#  'budget on 18th  \n'
#  'Feb, 1860.\n'
#  'Now the budget in India is presented on the first working day of February '
#  'each year .\n'
#  'Definition of Government Budget  - It is a financial statement showing '
#  'estimated  \n'
#  'receipts and estimated expenditures of the government during a fiscal year '
#  '(from 1st  \n'
#  'April to 31st March). The annual budget of the central govenment is titled '
#  'as ‘Union  \n'
#  'Budget’.\n'
#  'Features of Budget\n'
#  '1. It is an estimate, not an actual statement.\n'
#  '2. It is prepared annually .\n'
#  '3. It is a constitutional requirement to present the budget.\n'
#  '4. Revenue and expenditure are planned according to the objectives of the  \n'
#  'government.Macroeconomics\n'
#  '35. Budget impacts the economy through aggregate fiscal discipline and '
#  'resource  \n'
#  'allocation.\n'
#  'Objectives of Budget\n'
#  'Redistribution of income and wealth\n'
#  '1. The government aims at reducing economic disparity which is inherent in '
#  'any  \n'
#  'economic system.\n'
#  '2. The government aims at distributing income and wealth in such a manner '
#  'that  \n'
#  'there is social justice in the society which is the principal objective of '
#  'any  \n'
#  'welfare state like India.\n'
#  '3. Governement uses its fiscal tools i.e. taxes and subsidies to promote '
#  'social  \n'
#  'welfare.\n'
#  '4. To improve the distribution of income and wealth, higher taxes can be '
#  'imposed  \n'
#  'by the government on the income earned by the rich people.\n'
#  '5. Those with very low income are exempt from payment of taxes.\n'
#  '6. Also, subsidies are of fered to the poorer sections of the society and '
#  'government  \n'
#  'can provide free services of education and health to increase their '
#  'disposable  \n'
#  'income.\n'
#  '7. Also, essential food items are provided to BPL  families at subsidised '
#  'rate  \n'
#  'through fair price shops.\n'
#  '8. The government makes these provisions in its annual budget.\n'
#  'Reallocation of resources\n'
#  '1. It refers to change in the decision/direction of resources from one use '
#  'to  \n'
#  'another .\n'
#  '2. The government seeks reallocation of resources with a view to balance the '
#  'goal  \n'
#  'of profit maximization and social welfare.\n'
#  '3. Production of goods which are injurious to health is discouraged through '
#  'heavy  \n'
#  'taxation.Macroeconomics\n'
#  '44. On the other hand, production of socially useful goods is encouraged '
#  'through  \n'
#  'subsidies.\n'
#  '5. Through budgetary policy , government makes suf ficient provisions for '
#  'the  \n'
#  'supply of public goods.\n'
#  '6. Also, subsidies are of fered for the use of LPG and CNG.\n'
#  '7. If private sector does not take initiative in certain activities, then '
#  'government  \n'
#  'directly controls them like sanitation. It is also known as allocation '
#  'function.\n'
#  'Economic Stability/Price Stability\n'
#  '1. Free play of market forces generates trade cycle/business cycle i.e. '
#  'phases of  \n'
#  'Boom, Recession, Depression and Reecovery .\n'
#  '2. Budget is used as an important policy instrument to solve the problem '
#  'of  \n'
#  'inflation and deflation i.e. fiscal policy of the government related to '
#  'government  \n'
#  'expenditure and government receipts.\n'
#  '3. Volatile economies (unstable economies) do not provide friendly '
#  'environment  \n'
#  'for domestic investments as well as FDI (Foreign Direct Investment).  \n'
#  'Accordingly , pace of economic growth suf fers.\n'
#  '4. Economic stability induces investment in the economy .\n'
#  '5. During recession or deflation, government can increase its expenditure '
#  'and  \n'
#  'reduce receipts. In other words, during recession, investment can take a '
#  'boost  \n'
#  'through tax break and of fering subsidies.\n'
#  '6. During inflation, government reduces its expenditure and increases its '
#  'receipts  \n'
#  'i.e government may enforce increase in tax and reduction in subsidies to  \n'
#  'withdraw excess money supply from the economy .\n'
#  '7. So it is stabilising function so that government brings economic '
#  'stability and  \n'
#  'increases the rate of economic growth and development.\n'
#  'Economic Growth\n'
#  '1. Economic growth has been one of the key objectives of the budget.\n'
#  '2. A sustainable increase in real GDP  signifies economic '
#  'growth.Macroeconomics\n'
#  '53. It happens when there is increase in the volume of goods and services  \n'
#  'produced in the economy .\n'
#  '4. Government budget can be an ef fective tool to ensure economic growth in '
#  'the  \n'
#  'economy .\n'
#  '5. Government makes various policies and provisions through its budgetary '
#  'policy  \n'
#  'to stimulate savings and investment in the economy .\n'
#  '6. This will enhance capital formation in the economy with increase in level '
#  'of  \n'
#  'production, rise in national income and economic growth.\n'
#  '7. This is done by providing tax rebate or tax holiday and other incentives '
#  'for  \n'
#  'productive ventures.\n'
#  '8. Government spends on basic services and facilities to have a strong  \n'
#  'infrastructural base of the economy like government increasing its '
#  'expenditure  \n'
#  'on health, education, transportation etc. so that level of production rises '
#  'in both  \n'
#  'private and public sector .\n'
#  '9. Government also ensures that while planning its expenditure and '
#  'revenue  \n'
#  'policy , fiscal discipline is maintained and inflation and deflation are '
#  'under  \n'
#  'control.\n'
#  'Generation of Employment  - In this regard, governemnt needs to promote '
#  'labour  \n'
#  'absorbing technology , public work programs like construction of roads, dams '
#  'etc.  \n'
#  'and to undertake employment specific projects/schemes (to reduce poverty).\n'
#  'Managing Public Enterprises \n'
#  '1. Government  establishes public enterprises with a view of social '
#  'interest.\n'
#  '2. Budget is prepared with the objective of making various provisions for  \n'
#  'managing such enterprises and providing them financial help in case they '
#  'have  \n'
#  'become sick units.\n'
#  '3. The government aims at providing ef fective and ef ficient availability '
#  'of  \n'
#  'government services which is a major source of government revenue.\n'
#  'Fiscal Discipline  Macroeconomics\n'
#  '61. Fiscal Discipline refers to ideal balance between the government '
#  'expenditure and  \n'
#  'government revenue.\n'
#  '2. If this discipline is not maintained, often the government is driven in '
#  'the state where  \n'
#  'government expenditure is more than its revenue.\n'
#  '3. In such a situation, government resorts to borrowing from RBI (or '
#  'printing of  \n'
#  'additional currency) i.e. deficit financing.\n'
#  '4. This increases the money supply and causes inflation (in case of excess '
#  'money  \n'
#  'supply).\n'
#  'Structure/Components of Budget\n'
#  'Budget Receipts\n'
#  'Revenue Receipts \n'
#  'Does not create any liability of the government\n'
#  'Does not lead to reduction in the assets\n'
#  'Examples - Tax and Non-T ax Revenue Receipts\n'
#  'Non-T ax Revenue Receipt Examples\n'
#  'Interest Receipts\n'
#  'Profits or dividends received by public enterprises\n'
#  'Fees and fines\n'
#  'Receipts of gifts, grants, donations etc.\n'
#  'Special Assessments.\n'
#  'Escheat -  Income of the government from the property left out by  \n'
#  'the people without a legal heir/claimant\n'
#  'Capital Receipts\n'
#  'Creates or increases liability of the government\n'
#  'Leads to reduction in the assets of government\n'
#  'ExamplesMacroeconomics\n'
#  '7Recovery of loans\n'
#  'Borrowings and other liabilities (can be from the general public, RBI  \n'
#  'or the rest of the world)\n'
#  'Disinvestment\n'
#  'Other Receipts like Provident Funds\n'
#  'Budget Expenditure\n'
#  'Capital Expenditure\n'
#  'Leads to reduction in liability\n'
#  'Creates assets of the government\n'
#  'Examples\n'
#  'Purchase of land and building or any other capital assert, then  \n'
#  'investment will create access\n'
#  'Loan to state governments and UT s\n'
#  'Repayment of loans\n'
#  'Revenue Expenditure\n'
#  'Does not lead to reduction in liability\n'
#  'Does not create any assets\n'
#  'Tax\n'
#  'Tax is a compulsory and unilateral payment to the government without '
#  'expectation of  \n'
#  'direct benefit to the taxpayer .\n'
#  'Types of T axes\n'
#  'Direct T ax\n'
#  'If the liability to pay the tax and its burden falls on the same person, it '
#  'is  \n'
#  'termed as direct tax.\n'
#  'Burden of direct tax cannot be shifted to other people.Macroeconomics\n'
#  '8Direct taxes are generally levied on income and wealth. Example - Income  \n'
#  'Tax, Corporation Tax, Gift Tax etc.\n'
#  'These are progressive in nature (i.e. burden is more on rich and less on  \n'
#  'poor).\n'
#  'Indirect T ax\n'
#  'If the liability to pay tax and its burden falls on dif ferent people it is '
#  'called  \n'
#  'indirect tax.\n'
#  'Burden of indirect tax can be shifted on others.\n'
#  'These are generally imposed on goods and services. Example - GST , VAT \n'
#  'etc.\n'
#  'These are regressive in nature (burden is more on the poor and less on '
#  'the  \n'
#  'rich).\n'
#  'Types of Budget\n'
#  'Balanced Budget - When expenditure is equal to receipts\n'
#  'Surplus Budget - When estimated receipts are more than estimated '
#  'expenditure\n'
#  'Deficit Budget  - When government expenditure is more than receipts\n'
#  'Goals of Government for Spending Money\n'
#  'Economic Growth\n'
#  'Social W elfare\n'
#  'Defence and law & order\n'
#  'Reducing inequality\n'
#  'Correcting inflation and deflation\n'
#  'Balanced regional growthMacroeconomics\n'
#  '9Budget Deficit and Measures\n'
#  'Budget Deficit\n'
#  '1. It is a situation of mismatch between receipts and expenditures of the  \n'
#  'government mainly when government expenditure is more than government  \n'
#  'receipts.\n'
#  '2. There are three measures of deficit - Revenue Deficit, Fiscal Deficit and '
#  'Primary\n'
#  'Deficit.\n'
#  'Revenue Deficit\n'
#  '1. It refers to excess of revenue expenditure over revenue receipts : \n'
#  ' RD = RE - RR\n'
#  '2. It tells that revenue receipts fall short of revenue expenditure which  \n'
#  'indicates dissavings.\n'
#  '3. It signifies that government has to make up for this short fall from  \n'
#  'capital receipts i.e. through borrowings or through sale of assets.\n'
#  '4. So the revenue deficit may thus result into either in the increase in  \n'
#  'liabilities of the government or reduction in the assets.\n'
#  '5. A higher revenue deficit implies higher repayment burden in future.\n'
#  '6. It may lead to inflation-y situation in the economy .\n'
#  '7. For the growth of the economy , government should try to control the  \n'
#  'revenue deficit.\n'
#  '8. Two measures to correct revenue deficit are : Reduction in expenditure  \n'
#  'like reduction in subsidies or administrative expenses etc. or Increase '
#  'in  \n'
#  'revenue by imposing higher taxes and fines etc.\n'
#  'Fiscal Deficit\n'
#  '1. Fiscal Deficit refers to excess of total expenditure over total '
#  'receipts  \n'
#  'excluding borrowings.\n'
#  '2. Fiscal Deficit basically signifies borrowings only . From economic '
#  'point  \n'
#  'of view , a safe level of fiscal deficit is 5% of GDP . \n'
#  '3. Fiscal Deficit can be calculated as follows : RD= RE− RRMacroeconomics\n'
#  '10a. Fiscal Deficit = Total Expenditures - Total Receipts (excluding  \n'
#  'borrowings)\n'
#  'b. Fiscal Deficit = Budget Deficit + Borrowings (here Budget Deficit =  \n'
#  'Total Expenditure - Total Receipts)\n'
#  'c. Fiscal Deficit = Revenue Deficit + Capital Expenditure - Capital  \n'
#  'Receipts excluding Borrowings\n'
#  '4. Fiscal Deficit leads to inflationary pressure in an economy as more  \n'
#  'borrowings lead to increase in money supply and this increase in  \n'
#  'money supply often causes rise in price levels.\n'
#  '5. It may lead to foreign dependence as government has to borrow from  \n'
#  'international sources also.\n'
#  '6. Debt T rap -  It is a situation where government is forced to borrow  \n'
#  'money to finance its interest payments and these borrowings are also  \n'
#  'to be repaid with interest. To finance this interest, the government '
#  'takes  \n'
#  'more borrowings and this repeated cycle leads to a vicious circle and  \n'
#  'causes Debt Trap.\n'
#  '7. Fiscal Deficit creates financial burden for future generations.\n'
#  '8. High Fiscal Deficit generally leads to wasteful and unnecessary  \n'
#  'expenditure of the government.\n'
#  '9. The Fiscal Deficit can be financed in three ways : \n'
#  'a. Deficit Financing  - The Central bank may finance the government  \n'
#  'by printing money equal to the deficit. Government borrows money  \n'
#  'from the Central Bank i.e RBI against securities or Treasury Bills. In  \n'
#  'old terminology , it was known as Deficit Financing and now it is  \n'
#  'called Monetisation of Fiscal Deficit.\n'
#  'b. Borrowings from the Public - The Budget Deficit can be financed  \n'
#  'by borrowing money from the public through Market Loans by  \n'
#  'issuing Bonds. This is known as Debt-Financed Budget Deficit.\n'
#  'c. Borrowings from External Sources - World Bank, IMF etc.Macroeconomics\n'
#  '11Primary Deficit \n'
#  'Primary Deficit is defined as Fiscal Deficit without the Interest '
#  'Payments  \n'
#  ': PD = FD - Net Interest Payments\n'
#  'Here :  Net Interest Payments = Interest Payments - Interest Received\n'
#  'Fiscal Deficit indicates borrowings including Interest Payments while  \n'
#  'Primary Deficit indicates borrowings excluding Interest Payments.\n'
#  'In short, Primary Deficit indicates borrowing requirements of the  \n'
#  'government to meet Fiscal Deficit net of Interest Payments. It enables  \n'
#  'us to see the way the government is currently conducting its financial  \n'
#  'affairs.\n'
#  'Banking\n'
#  'Central Bank\n'
#  'There is one apex institution which acts as the leader of the money market. '
#  'It  \n'
#  'supervises, regulates and controls the activities of the commercial banks '
#  'and other  \n'
#  'financial institutions. Such an institution is called Central Bank of the '
#  'country .\n'
#  'A Central Bank is so called because it occupies the central or highest '
#  'position in the  \n'
#  'monetary or banking structure of the country .\n'
#  'In India, RBI is the Central Bank of the country .\n'
#  'Functions of Central Bank\n'
#  'Bank of Issue / Currency Authority\n'
#  'It is the primary function of the Central bank to issue the currency .\n'
#  'In India, RBI has the sole right of issuance of currency notes (except One-\n'
#  'Rupee note which is issued by Ministry of Finance).\n'
#  'The Central Bank keeps three main considerations regarding issuance of  \n'
#  'notes i.e. uniformity , elasticity and safety .Macroeconomics\n'
#  '12The RBI tries to keep money growth within a target range and thus keeps  \n'
#  'inflationary pressure at a low level.\n'
#  'The Central Bank is obliged to back the currency with assets such as '
#  'gold,  \n'
#  'foreign securities and other approved securities.\n'
#  'Notes issued by RBI are unlimited legal tender .\n'
#  'In India, RBI issues notes on the basis of minimum reserve system.\n'
#  'Banker to the Government\n'
#  'Central Bank is like banker , agent and adviser to the government.\n'
#  'As a Banker\n'
#  'The Central Bank makes and recieves payments on the behalf of the  \n'
#  'government.\n'
#  'It helps the government with short term loans and advances in times of  \n'
#  'difficulty\n'
#  'Sometimes government borrows money to finance its Budget Deficit.\n'
#  'As an Agent -  The Central Bank conducts sale and purchase of  \n'
#  'government securities and also manages national/public debt as well as  \n'
#  'foreign debt of the governmen\n'
#  'As an Adviser -  The Central Bank acts as an adviser to the government  \n'
#  'specially on monetary , banking and financial matters.\n'
#  'Controller of Money Supply and Credit\n'
#  'Controlling of money supply and credit is another important function of RBI\n'
#  'Through this function, the Central Bank attempts to influence and cotnrol  \n'
#  'the volume of Bank Credit and economic activity in the country .\n'
#  'Central Bank can control inflationary and deflationary situations in the  \n'
#  'economy through credit control measures which are termed as Instruments  \n'
#  'of Monetary Policy .\n'
#  'During Inflation, RBI adopts Dear Monetary Policy by making the credit  \n'
#  'costlier or reducing the flow of credit in the system.Macroeconomics\n'
#  '13During Deflation, Central Bank adopts Cheap Montary Policy by making  \n'
#  'credit cheaper or expanding the flow of credit in the system.\n'
#  'Bankers’  Bank and Supervision\n'
#  'Central Bank is the agency to regulate and supervise the functioning of  \n'
#  'commercial banks. Being the apex bank, the Central Bank acts as the  \n'
#  'banker to other banks. In this sense, it bears the same relation with  \n'
#  'commercial banks as commercial banks maintain with general public.\n'
#  'As bankers’  bank, Central Bank functions in three capacities :\n'
#  'Custodian of Cash Reserves of commercial banks (CRR)  - \n'
#  'Commercial banks are required to keep a certain proportion of their  \n'
#  'deposits known as Cash Reserve Ratio (CRR) with the Central Bank.  \n'
#  'Advantages of Cash Reserve Ratio are : \n'
#  'This system results in ef fective utilization of the cash reserves of  \n'
#  'the country .\n'
#  'It reinforces the confidence of the public in the strength of banking  \n'
#  'system of the country .\n'
#  'It enables the Central Bank to control credit creation done by the  \n'
#  'commercial banks by changing the Cash Reserve Requirement.\n'
#  'Commercial Banks can get financial help from the Central Bank  \n'
#  'during temporary dif ficulties.\n'
#  'Lender of Last Resort - When commercial banks fail to meet their  \n'
#  'financial requirements from other sources i.e. in case of a financial  \n'
#  'emergency , they approach the Central Bank to give loans as a Lender  \n'
#  'of the Last Resort. A commercial bank can borrow from the Central  \n'
#  'Bank against eligible securities.\n'
#  'Clearing House - As Central Bank holds the cash reserves of all the  \n'
#  'commercial banks, it becomes easier and more convenient for it to act  \n'
#  'as their Clearing House. All commercial banks have their accounts with  \n'
#  'the Central Bank, therefore, the Central Bank can easily settle claims of  \n'
#  'various commercial banks against each other by making debit and  \n'
#  'credit entries in their account.Macroeconomics\n'
#  '14As a supervisor , Central Bank regulates and controls the commercial '
#  'banks.  \n'
#  'The regulation of banks may be related to their licensing, branch '
#  'expansion,  \n'
#  'liquidity of assets, merging, winding up, etc. The control is exercised '
#  'by  \n'
#  'periodic inspections of the banks and the returns filed by them.\n'
#  'Custodian of Nation’ s Reserve of International Currency/ Foreign  \n'
#  'Exchange Reserves - The Central bank is the custodian of the country’ s '
#  'stock  \n'
#  'of gold and international currencies. All the receipts and payments in '
#  'foreign  \n'
#  'exchange are maintained by the Central Bank. Through this function, '
#  'Central  \n'
#  'Bank maintains the rate of exchange and manages exchange control as well.\n'
#  'Credit Control Measures/Instruments of Monetary Policy\n'
#  'The Central bank is empowered to regulate the money supply in the economy '
#  'through  \n'
#  'its monetary policy . It is the policy adopted by the Central Bank in the '
#  'direction of credit  \n'
#  'control/money supply .\n'
#  'Credit control measures are broadly classified as Quantitative Credit '
#  'Control Measures  \n'
#  'and Qualitative Credit Control Measures.\n'
#  'Quantitative Credit Control Measures (General Control Measures) \n'
#  'These are the measures which are supposed to control the total volume of '
#  'bank : \n'
#  'Bank Rate (Discount Rate) - It is the rate at which Central Bank of a '
#  'country  \n'
#  'advances long-term loans to the commercial banks.\n'
#  'On the other hand, the rate at which commercial bank advances loans to  \n'
#  'general public is called Market Rate of Interest. \n'
#  'An increase in Bank Rate increases the cost of borrowings from the '
#  'Central  \n'
#  'Bank. It forces the commercial bank to increase their lending rates which  \n'
#  'discourages borrowers from taking loans so it reduces the ability of '
#  'commercial  \n'
#  'banks to create credit i.e. leads to contraction of credit and thereby , '
#  'controlling  \n'
#  'inflation.\n'
#  'A decrease in Bank Rate by RBI reduces the cost of borrowings for '
#  'commercial  \n'
#  'banks which leads to fall in their lending rates. This encourages the '
#  'borrowers  \n'
#  'to take loans so it increases the ability of commercial banks to create '
#  'credit i.e.  \n'
#  'it leads to expansion of credit and thereby , controlling '
#  'deflation.Macroeconomics\n'
#  '15Repo Rate (Repurchase Rate) - Repo Rate is the rate at which the '
#  'Central  \n'
#  'Bank of the country lends money to the commercial banks to meet their '
#  'short-\n'
#  'term needs. The Central Bank advances loan against approved or eligible  \n'
#  'securities. W orks same as Bank Rate.\n'
#  'Reverse Repo Rate (Reverse Repurchase Rate)\n'
#  'This is exact opposite of Repo Rate. It is the rate of interest at which  \n'
#  'commercial banks can deposit their surplus funds with the Central Bank '
#  '(for  \n'
#  'relatively short period of time). So it is the rate of interest at which '
#  'Central  \n'
#  'Bank accepts deposits from the commercial banks.\n'
#  'When Reverse Repo Rate is raised, it encourages the commercial banks to  \n'
#  'deposit their funds with the Central Bank. This has the negative ef fect '
#  'on  \n'
#  'lending capability of the commercial bank (so during inflation, Reverse  \n'
#  'Repo Rate is increased).\n'
#  'Lowering the Reverse Repo Rate discourages the commercial banks from  \n'
#  'depositing their funds with the Central Bank. This has positive ef fect on '
#  'the  \n'
#  'lending capability of the commercial bank so during deflation, Reverse  \n'
#  'Repo Rate is lowered.\n'
#  'Open Market Operations - It refers to the policy of sale and purchase of  \n'
#  'government securities in the open market by the Central Bank.\n'
#  'When RBI starts selling the securities in the market, it reduces the '
#  'reserves of  \n'
#  'the commercial banks which in turn reduces the credit creating capacity '
#  'of  \n'
#  'these banks, thus selling of securities reduces the availability of '
#  'credit/money  \n'
#  'supply in the economy (so RBI sells securities during inflation).\n'
#  'When RBI purchases the securities in the open market, it increases the  \n'
#  'reserves of the commercial bank which in turn increases the credit '
#  'creation  \n'
#  'capacity and therefore increases the money supply in the economy so '
#  'during  \n'
#  'deflation, Central Bank expands the credit with the purchase of securities.\n'
#  'Legal Reserve Requirement (V ariable Reserve Ratios)\n'
#  'Commercial banks are required to maintain certain reserves as a matter of '
#  'law  \n'
#  'which are called Legal Reserve Ratios. It is a very quick and direct method '
#  'for  \n'
#  'controlling the credit. Commercial banks are required to maintain two types '
#  'of  \n'
#  'reserves : Macroeconomics\n'
#  '16Cash Reserve Ratio (CRR) - Every commercial bank is required to keep a  \n'
#  'minimum percentage of its total deposits with the Central Bank. This is  \n'
#  'called CRR.\n'
#  'An increase in CRR reduces the cash reserves of the commercial banks  \n'
#  'which in turn reduces the credit creation capacity of the banks so during  \n'
#  'inflation, CRR is increased by RBI.\n'
#  'A decrease in CRR increases the cash reserves of thr banks which in turn  \n'
#  'increases their credit creation capacity . So during deflation, CRR is '
#  'reduced  \n'
#  'by RBI.\n'
#  'Statutory Liquidity Ratio (SLR) - It is the minimum amount of deposits  \n'
#  'which commercial banks are required to maintain with themselves in form '
#  'of  \n'
#  'designated liquid assets.\n'
#  'An increase in SLR reduces the credit creation capacity of the bank. On '
#  'the  \n'
#  'other hand, decrease in SLR increases their credit creation capacity . So \n'
#  'during inflation, SLR is increased and during deflation, SLR is lowered '
#  'by  \n'
#  'RBI.\n'
#  'Qualitative Instruments/Specific Credit Control Measures\n'
#  'The credit control measures which are controlling certain kinds of credit or '
#  'af fect the  \n'
#  'flow of credit for a particular use are called Qualitative Instruments.\n'
#  'Qualitative Controls are designed to regulate the direction of credit. They '
#  'are also  \n'
#  'called Selective Credit Control Measures.  \n'
#  '1. Margin Requirement - The dif ference between the value of Security and '
#  'the  \n'
#  'amount of loan is called Margin Requirement. By changing the Margin  \n'
#  'Requirement, the Central Bank can expand or contract the credit creating  \n'
#  'capacity of commercial banks.\n'
#  'For example, if Margin fixed by Central Bank is 20%, then commercial '
#  'banks  \n'
#  'are allowed to give a loan only upto 80% of the value of the Security .\n'
#  'An increase in Margin reduces the borrowing capacity of the people and a '
#  'fallen  \n'
#  'Margin encourages the people to borrow more.Macroeconomics\n'
#  '17RBI may prescribe dif ferent Margins for dif ferent types of borrowers '
#  'against the  \n'
#  'Security of the same commodity .\n'
#  'Margin is necessary because if a bank gives a loan equal to full value of  \n'
#  'Security , then bank will suf fer a loss in case of fallen price of Security '
#  '.\n'
#  '2. Moral Suasion - Moral Suasion implies persuasion, request, informal  \n'
#  'suggestion, advice and appeal by the Central Bank to commercial banks to '
#  'co-\n'
#  'operate with the general monetary policy of the Central Bank. Generally , '
#  'Central  \n'
#  'Bank succeeds in convincing the banks as it acts as their Lender of Last '
#  'Resort  \n'
#  '(Moral Suasion can be used for both Quantitative as well as Qualitative '
#  'Control  \n'
#  'Measure but more often it is classified as Qualitative Instrument).\n'
#  '3. Credit Rationing - In this method, the Central Bank can give directions '
#  'to the  \n'
#  'commercial bank not to give credit for certain purposes or to give more '
#  'credit  \n'
#  'for particular purposes or to the priority sectors.\n'
#  'Commercial Banks\n'
#  'Commercial bank is a financial institution which performs the function of '
#  'accepting  \n'
#  'deposit and advancing loans with the aim of earning profits.\n'
#  'The household sector saves a part of its income which is made available to '
#  'the  \n'
#  'productive sector for further investment.\n'
#  'Commercial banks act as a financial intermediary whose main function is to '
#  'collect  \n'
#  'savings from the household sector and lend it to the productive sector .\n'
#  'The rate of interest at which commercial bank accepts deposit is known as  \n'
#  'borrowing rate and the rate at which banks lend out the reserves to '
#  'investors is  \n'
#  'called Lending Rate. \n'
#  'The dif ference between the two rates known as Spread is profit earned by '
#  'the  \n'
#  'banks.\n'
#  'Structure of Commercial Banks in India\n'
#  'Scheduled BanksMacroeconomics\n'
#  '18Scheduled Banks are those banks which have been included in the Second  \n'
#  'Schedule of RBI Act, 1934. In India, scheduled commercial banks are fo three '
#  'types  \n'
#  ': \n'
#  'Public Sector Banks - These banks are owned and controlled by the  \n'
#  'government. The main objective of these banks is to provide service to '
#  'the  \n'
#  'society like, SBI, Bank of India (BoI), PNB, Canara Bank etc.\n'
#  'Private Sector Banks - These banks are owned and controlled by private  \n'
#  'sector . Their main objective is to earn profit. Example - ICICI, HDFC, Axis '
#  'Bank  \n'
#  'etc.\n'
#  'Foreign Banks - These banks are owned and controlled by foreign '
#  'promoters.  \n'
#  'Example - Standard Chartered Bank, American Express Bank etc. Their '
#  'number  \n'
#  'has grown rapidly since 1991 when the process of economic liberalization '
#  'had  \n'
#  'started in India.\n'
#  'Non-Scheduled Banks - Non-Scheduled Banks refers to those banks which are  \n'
#  'not included in the Second Schedule of RBI Act, 1934. Example - Hindustan '
#  'Co-\n'
#  'operative Bank Limited, The Tirupati Co-operative Bank Limited etc.\n'
#  'Functions of Commercial Banks\n'
#  'There can be following types of functions of commercial banks : \n'
#  'Primary Functions\n'
#  'According to the Banking Regulation Act, 1949, “A  banking company is '
#  'defined  \n'
#  'as a company which transacts the business of banking in India” and the '
#  'word  \n'
#  'banking is defined as “the acceptance for the purpose of lending and '
#  'investment  \n'
#  'of deposit of money from the public repayable on demand or otherwise and  \n'
#  'withdrawable by cheque, draft, order or otherwise”. Primary functions can '
#  'be  \n'
#  'explained as : \n'
#  'Accepting of Deposits \n'
#  'The primary or basic function of commercial bank is to accept deposit  \n'
#  'from the public and the funds so collected are then of fered as loans to  \n'
#  'those who need it.Macroeconomics\n'
#  '19The bank does act as an intermediary between the two i.e. by accepting  \n'
#  'deposit from public having excess cash and paying interest on it and  \n'
#  'lending loan to needy and charging higher rate of interest on it.\n'
#  'Commercial banks accepts following types of deposits : \n'
#  'Demand Deposits/Current Account \n'
#  'A Current Account is usually held by businessmen, industrial  \n'
#  'enterprises, corporations, etc.\n'
#  'These deposits are those deposits which are repayable by the  \n'
#  'banks on demand.\n'
#  'There are no restrictions on the amount of deposits and  \n'
#  'withdrawals.\n'
#  'Normally , banks do not pay any interest on these accounts,  \n'
#  'rather banks impose some charges for providing facilities on  \n'
#  'these accounts.\n'
#  'Saving Account/Saving Deposits \n'
#  'These deposits are generally opened by salaried class or  \n'
#  'middle income group who save a small portion of their income  \n'
#  'and deposit the same with the bank.\n'
#  'A small rate of interest is paid on this account by the banks and  \n'
#  'the withdrawals are subjected to restrictions.\n'
#  'Time Deposits\n'
#  'These are the deposits which are repayable after a certain period of  \n'
#  'time. These are of two types : \n'
#  'Fixed Deposit : In a Fixed Deposit, a fixed amount is deposited  \n'
#  'with the bank for a fixed amount of time, say , 2 years, 3 years or  \n'
#  '5 years. The rate of interest of fered is highest. However , such  \n'
#  'rates vary with the period of time for which money is deposited.\n'
#  'Recurring Deposit\n'
#  'In this type of account, a depositor makes a regular deposit  \n'
#  'of a fixed amount every month for a fixed period of time.Macroeconomics\n'
#  '20The depositor cannot withdraw the amount before the expiry  \n'
#  'date (except in certain conditions).\n'
#  'The interest in this account is higher than Saving Account  \n'
#  'but lower than Fixed Deposits.\n'
#  'Advancing of Loans\n'
#  'The deposits received by banks are not allowed to remain idle. So after  \n'
#  'keeping certain Cash Reserves, the balance is given to the needy '
#  'borrowers  \n'
#  'in form of loans and advances and charges interest from them which is the  \n'
#  'main source of income for the banks.\n'
#  'Different types of loans and advances made by commercial banks are : \n'
#  'Cash Credit\n'
#  'It refers to the loan given to the borrower against certain collateral  \n'
#  'securities that the customer has to of fer to the bank.\n'
#  'Under this, a separate Cash Credit account is opened and the  \n'
#  'customer can borrow the funds from this account up to a certain  \n'
#  'limit.\n'
#  'The withdrawals are subject to restrictions i.e. borrower may  \n'
#  'withdraw any amount within his credit limit and interest is charged  \n'
#  'on the amount actually withdrawn.\n'
#  'Demand Loans\n'
#  'Demand Loans refers to those loans which can be recalled on  \n'
#  'demand by banks at any time. \n'
#  'These loans are genrally taken by Stock Brokers.\n'
#  'These loans are provided for a shorter period. Interest is payable on  \n'
#  'the entire amount.\n'
#  'Overdraft Facility - It refers to facility in which a customer is allowed '
#  'to  \n'
#  'overdraw his current account upon an agreed limit. This facility is  \n'
#  'generally given to reliable customers for a short period. Customers have  \n'
#  'to pay interest to the bank on the amount overdrawn by them.\n'
#  'Secondary FunctionsMacroeconomics\n'
#  '21Contingent Functions')

# %%
print(summarize(fulltext))
# Out:
# ('Definition of Government Budget  - It is a financial statement showing '
#  'estimated  \n'
#  'receipts and estimated expenditures of the government during a fiscal year '
#  '(from 1st  \n'
#  'Budget impacts the economy through aggregate fiscal discipline and '
#  'resource  \n'
#  '3. Governement uses its fiscal tools i.e. taxes and subsidies to promote '
#  'social  \n'
#  '8. The government makes these provisions in its annual budget.\n'
#  'expenditure and government receipts.\n'
#  '5. During recession or deflation, government can increase its expenditure '
#  'and  \n'
#  '6. During inflation, government reduces its expenditure and increases its '
#  'receipts  \n'
#  'i.e government may enforce increase in tax and reduction in subsidies to  \n'
#  'increases the rate of economic growth and development.\n'
#  '4. Government budget can be an ef fective tool to ensure economic growth in '
#  'the  \n'
#  'infrastructural base of the economy like government increasing its '
#  'expenditure  \n'
#  '9. Government also ensures that while planning its expenditure and '
#  'revenue  \n'
#  'Fiscal Discipline refers to ideal balance between the government expenditure '
#  'and  \n'
#  'government expenditure is more than its revenue.\n'
#  '3. In such a situation, government resorts to borrowing from RBI (or '
#  'printing of  \n'
#  'Creates or increases liability of the government\n'
#  'Borrowings and other liabilities (can be from the general public, RBI  \n'
#  'Deficit Budget  - When government expenditure is more than receipts\n'
#  '7. For the growth of the economy , government should try to control the  \n'
#  '8. Two measures to correct revenue deficit are : Reduction in expenditure  \n'
#  '1. Fiscal Deficit refers to excess of total expenditure over total '
#  'receipts  \n'
#  'Fiscal Deficit = Total Expenditures - Total Receipts (excluding  \n'
#  '5. It may lead to foreign dependence as government has to borrow from  \n'
#  '7. Fiscal Deficit creates financial burden for future generations.\n'
#  'a. Deficit Financing  - The Central bank may finance the government  \n'
#  'Government borrows money  \n'
#  'from the Central Bank i.e RBI against securities or Treasury Bills.\n'
#  'b. Borrowings from the Public - The Budget Deficit can be financed  \n'
#  'by borrowing money from the public through Market Loans by  \n'
#  'c. Borrowings from External Sources - World Bank, IMF etc.Macroeconomics\n'
#  'Fiscal Deficit indicates borrowings including Interest Payments while  \n'
#  'In short, Primary Deficit indicates borrowing requirements of the  \n'
#  'government to meet Fiscal Deficit net of Interest Payments.\n'
#  'supervises, regulates and controls the activities of the commercial banks '
#  'and other  \n'
#  'Such an institution is called Central Bank of the country .\n'
#  'In India, RBI is the Central Bank of the country .\n'
#  'Functions of Central Bank\n'
#  'It is the primary function of the Central bank to issue the currency .\n'
#  'The Central Bank is obliged to back the currency with assets such as '
#  'gold,  \n'
#  'Central Bank is like banker , agent and adviser to the government.\n'
#  'The Central Bank makes and recieves payments on the behalf of the  \n'
#  'It helps the government with short term loans and advances in times of  \n'
#  'Sometimes government borrows money to finance its Budget Deficit.\n'
#  'government securities and also manages national/public debt as well as  \n'
#  'As an Adviser -  The Central Bank acts as an adviser to the government  \n'
#  'Controlling of money supply and credit is another important function of RBI\n'
#  'Through this function, the Central Bank attempts to influence and cotnrol  \n'
#  'the volume of Bank Credit and economic activity in the country .\n'
#  'Central Bank can control inflationary and deflationary situations in the  \n'
#  'economy through credit control measures which are termed as Instruments  \n'
#  '13During Deflation, Central Bank adopts Cheap Montary Policy by making  \n'
#  'Central Bank is the agency to regulate and supervise the functioning of  \n'
#  'Custodian of Cash Reserves of commercial banks (CRR)  - \n'
#  'Commercial banks are required to keep a certain proportion of their  \n'
#  'deposits known as Cash Reserve Ratio (CRR) with the Central Bank.\n'
#  'It enables the Central Bank to control credit creation done by the  \n'
#  'commercial banks by changing the Cash Reserve Requirement.\n'
#  'Commercial Banks can get financial help from the Central Bank  \n'
#  'emergency , they approach the Central Bank to give loans as a Lender  \n'
#  'A commercial bank can borrow from the Central  \n'
#  'Clearing House - As Central Bank holds the cash reserves of all the  \n'
#  'All commercial banks have their accounts with  \n'
#  '14As a supervisor , Central Bank regulates and controls the commercial '
#  'banks.\n'
#  'Exchange Reserves - The Central bank is the custodian of the country’ s '
#  'stock  \n'
#  'Bank maintains the rate of exchange and manages exchange control as well.\n'
#  'The Central bank is empowered to regulate the money supply in the economy '
#  'through  \n'
#  'It is the policy adopted by the Central Bank in the direction of credit  \n'
#  'advances long-term loans to the commercial banks.\n'
#  'On the other hand, the rate at which commercial bank advances loans to  \n'
#  'An increase in Bank Rate increases the cost of borrowings from the '
#  'Central  \n'
#  'It forces the commercial bank to increase their lending rates which  \n'
#  'discourages borrowers from taking loans so it reduces the ability of '
#  'commercial  \n'
#  'banks to create credit i.e. leads to contraction of credit and thereby , '
#  'controlling  \n'
#  'A decrease in Bank Rate by RBI reduces the cost of borrowings for '
#  'commercial  \n'
#  'banks which leads to fall in their lending rates.\n'
#  'to take loans so it increases the ability of commercial banks to create '
#  'credit i.e.\n'
#  'it leads to expansion of credit and thereby , controlling '
#  'deflation.Macroeconomics\n'
#  'Bank of the country lends money to the commercial banks to meet their '
#  'short-\n'
#  'The Central Bank advances loan against approved or eligible  \n'
#  'commercial banks can deposit their surplus funds with the Central Bank '
#  '(for  \n'
#  'When Reverse Repo Rate is raised, it encourages the commercial banks to  \n'
#  'lending capability of the commercial bank (so during inflation, Reverse  \n'
#  'Lowering the Reverse Repo Rate discourages the commercial banks from  \n'
#  'depositing their funds with the Central Bank.\n'
#  'depositing their funds with the Central Bank.\n'
#  'lending capability of the commercial bank so during deflation, Reverse  \n'
#  'government securities in the open market by the Central Bank.\n'
#  'the commercial banks which in turn reduces the credit creating capacity '
#  'of  \n'
#  'these banks, thus selling of securities reduces the availability of '
#  'credit/money  \n'
#  'reserves of the commercial bank which in turn increases the credit '
#  'creation  \n'
#  'deflation, Central Bank expands the credit with the purchase of securities.\n'
#  'Commercial banks are required to maintain certain reserves as a matter of '
#  'law  \n'
#  'Commercial banks are required to maintain two types of  \n'
#  '16Cash Reserve Ratio (CRR) - Every commercial bank is required to keep a  \n'
#  'minimum percentage of its total deposits with the Central Bank.\n'
#  'An increase in CRR reduces the cash reserves of the commercial banks  \n'
#  'which in turn reduces the credit creation capacity of the banks so during  \n'
#  'A decrease in CRR increases the cash reserves of thr banks which in turn  \n'
#  'which commercial banks are required to maintain with themselves in form '
#  'of  \n'
#  'An increase in SLR reduces the credit creation capacity of the bank.\n'
#  'Requirement, the Central Bank can expand or contract the credit creating  \n'
#  'capacity of commercial banks.\n'
#  'For example, if Margin fixed by Central Bank is 20%, then commercial '
#  'banks  \n'
#  'operate with the general monetary policy of the Central Bank.\n'
#  '3. Credit Rationing - In this method, the Central Bank can give directions '
#  'to the  \n'
#  'commercial bank not to give credit for certain purposes or to give more '
#  'credit  \n'
#  'Commercial bank is a financial institution which performs the function of '
#  'accepting  \n'
#  'Commercial banks act as a financial intermediary whose main function is to '
#  'collect  \n'
#  'The rate of interest at which commercial bank accepts deposit is known as  \n'
#  'borrowing rate and the rate at which banks lend out the reserves to '
#  'investors is  \n'
#  'Structure of Commercial Banks in India\n'
#  'In India, scheduled commercial banks are fo three types  \n'
#  'Functions of Commercial Banks\n'
#  'There can be following types of functions of commercial banks : \n'
#  'The primary or basic function of commercial bank is to accept deposit  \n'
#  'Commercial banks accepts following types of deposits : \n'
#  'and deposit the same with the bank.\n'
#  'Different types of loans and advances made by commercial banks are : ')

# %%
print(summarize(fulltext, split=True))
# Out:
# ['Definition of Government Budget  - It is a financial statement showing '
#  'estimated  ',
#  'receipts and estimated expenditures of the government during a fiscal year '
#  '(from 1st  ',
#  'Budget impacts the economy through aggregate fiscal discipline and '
#  'resource  ',
#  '3. Governement uses its fiscal tools i.e. taxes and subsidies to promote '
#  'social  ',
#  '8. The government makes these provisions in its annual budget.',
#  'expenditure and government receipts.',
#  '5. During recession or deflation, government can increase its expenditure '
#  'and  ',
#  '6. During inflation, government reduces its expenditure and increases its '
#  'receipts  ',
#  'i.e government may enforce increase in tax and reduction in subsidies to  ',
#  'increases the rate of economic growth and development.',
#  '4. Government budget can be an ef fective tool to ensure economic growth in '
#  'the  ',
#  'infrastructural base of the economy like government increasing its '
#  'expenditure  ',
#  '9. Government also ensures that while planning its expenditure and revenue  ',
#  'Fiscal Discipline refers to ideal balance between the government expenditure '
#  'and  ',
#  'government expenditure is more than its revenue.',
#  '3. In such a situation, government resorts to borrowing from RBI (or '
#  'printing of  ',
#  'Creates or increases liability of the government',
#  'Borrowings and other liabilities (can be from the general public, RBI  ',
#  'Deficit Budget  - When government expenditure is more than receipts',
#  '7. For the growth of the economy , government should try to control the  ',
#  '8. Two measures to correct revenue deficit are : Reduction in expenditure  ',
#  '1. Fiscal Deficit refers to excess of total expenditure over total '
#  'receipts  ',
#  'Fiscal Deficit = Total Expenditures - Total Receipts (excluding  ',
#  '5. It may lead to foreign dependence as government has to borrow from  ',
#  '7. Fiscal Deficit creates financial burden for future generations.',
#  'a. Deficit Financing  - The Central bank may finance the government  ',
#  'Government borrows money  ',
#  'from the Central Bank i.e RBI against securities or Treasury Bills.',
#  'b. Borrowings from the Public - The Budget Deficit can be financed  ',
#  'by borrowing money from the public through Market Loans by  ',
#  'c. Borrowings from External Sources - World Bank, IMF etc.Macroeconomics',
#  'Fiscal Deficit indicates borrowings including Interest Payments while  ',
#  'In short, Primary Deficit indicates borrowing requirements of the  ',
#  'government to meet Fiscal Deficit net of Interest Payments.',
#  'supervises, regulates and controls the activities of the commercial banks '
#  'and other  ',
#  'Such an institution is called Central Bank of the country .',
#  'In India, RBI is the Central Bank of the country .',
#  'Functions of Central Bank',
#  'It is the primary function of the Central bank to issue the currency .',
#  'The Central Bank is obliged to back the currency with assets such as gold,  ',
#  'Central Bank is like banker , agent and adviser to the government.',
#  'The Central Bank makes and recieves payments on the behalf of the  ',
#  'It helps the government with short term loans and advances in times of  ',
#  'Sometimes government borrows money to finance its Budget Deficit.',
#  'government securities and also manages national/public debt as well as  ',
#  'As an Adviser -  The Central Bank acts as an adviser to the government  ',
#  'Controlling of money supply and credit is another important function of RBI',
#  'Through this function, the Central Bank attempts to influence and cotnrol  ',
#  'the volume of Bank Credit and economic activity in the country .',
#  'Central Bank can control inflationary and deflationary situations in the  ',
#  'economy through credit control measures which are termed as Instruments  ',
#  '13During Deflation, Central Bank adopts Cheap Montary Policy by making  ',
#  'Central Bank is the agency to regulate and supervise the functioning of  ',
#  'Custodian of Cash Reserves of commercial banks (CRR)  - ',
#  'Commercial banks are required to keep a certain proportion of their  ',
#  'deposits known as Cash Reserve Ratio (CRR) with the Central Bank.',
#  'It enables the Central Bank to control credit creation done by the  ',
#  'commercial banks by changing the Cash Reserve Requirement.',
#  'Commercial Banks can get financial help from the Central Bank  ',
#  'emergency , they approach the Central Bank to give loans as a Lender  ',
#  'A commercial bank can borrow from the Central  ',
#  'Clearing House - As Central Bank holds the cash reserves of all the  ',
#  'All commercial banks have their accounts with  ',
#  '14As a supervisor , Central Bank regulates and controls the commercial '
#  'banks.',
#  'Exchange Reserves - The Central bank is the custodian of the country’ s '
#  'stock  ',
#  'Bank maintains the rate of exchange and manages exchange control as well.',
#  'The Central bank is empowered to regulate the money supply in the economy '
#  'through  ',
#  'It is the policy adopted by the Central Bank in the direction of credit  ',
#  'advances long-term loans to the commercial banks.',
#  'On the other hand, the rate at which commercial bank advances loans to  ',
#  'An increase in Bank Rate increases the cost of borrowings from the Central  ',
#  'It forces the commercial bank to increase their lending rates which  ',
#  'discourages borrowers from taking loans so it reduces the ability of '
#  'commercial  ',
#  'banks to create credit i.e. leads to contraction of credit and thereby , '
#  'controlling  ',
#  'A decrease in Bank Rate by RBI reduces the cost of borrowings for '
#  'commercial  ',
#  'banks which leads to fall in their lending rates.',
#  'to take loans so it increases the ability of commercial banks to create '
#  'credit i.e.',
#  'it leads to expansion of credit and thereby , controlling '
#  'deflation.Macroeconomics',
#  'Bank of the country lends money to the commercial banks to meet their short-',
#  'The Central Bank advances loan against approved or eligible  ',
#  'commercial banks can deposit their surplus funds with the Central Bank '
#  '(for  ',
#  'When Reverse Repo Rate is raised, it encourages the commercial banks to  ',
#  'lending capability of the commercial bank (so during inflation, Reverse  ',
#  'Lowering the Reverse Repo Rate discourages the commercial banks from  ',
#  'depositing their funds with the Central Bank.',
#  'depositing their funds with the Central Bank.',
#  'lending capability of the commercial bank so during deflation, Reverse  ',
#  'government securities in the open market by the Central Bank.',
#  'the commercial banks which in turn reduces the credit creating capacity of  ',
#  'these banks, thus selling of securities reduces the availability of '
#  'credit/money  ',
#  'reserves of the commercial bank which in turn increases the credit '
#  'creation  ',
#  'deflation, Central Bank expands the credit with the purchase of securities.',
#  'Commercial banks are required to maintain certain reserves as a matter of '
#  'law  ',
#  'Commercial banks are required to maintain two types of  ',
#  '16Cash Reserve Ratio (CRR) - Every commercial bank is required to keep a  ',
#  'minimum percentage of its total deposits with the Central Bank.',
#  'An increase in CRR reduces the cash reserves of the commercial banks  ',
#  'which in turn reduces the credit creation capacity of the banks so during  ',
#  'A decrease in CRR increases the cash reserves of thr banks which in turn  ',
#  'which commercial banks are required to maintain with themselves in form of  ',
#  'An increase in SLR reduces the credit creation capacity of the bank.',
#  'Requirement, the Central Bank can expand or contract the credit creating  ',
#  'capacity of commercial banks.',
#  'For example, if Margin fixed by Central Bank is 20%, then commercial banks  ',
#  'operate with the general monetary policy of the Central Bank.',
#  '3. Credit Rationing - In this method, the Central Bank can give directions '
#  'to the  ',
#  'commercial bank not to give credit for certain purposes or to give more '
#  'credit  ',
#  'Commercial bank is a financial institution which performs the function of '
#  'accepting  ',
#  'Commercial banks act as a financial intermediary whose main function is to '
#  'collect  ',
#  'The rate of interest at which commercial bank accepts deposit is known as  ',
#  'borrowing rate and the rate at which banks lend out the reserves to '
#  'investors is  ',
#  'Structure of Commercial Banks in India',
#  'In India, scheduled commercial banks are fo three types  ',
#  'Functions of Commercial Banks',
#  'There can be following types of functions of commercial banks : ',
#  'The primary or basic function of commercial bank is to accept deposit  ',
#  'Commercial banks accepts following types of deposits : ',
#  'and deposit the same with the bank.',
#  'Different types of loans and advances made by commercial banks are : ']

# %%
print(summarize(fulltext, ratio=0.1, split=True))
# Out:
# ['receipts and estimated expenditures of the government during a fiscal year '
#  '(from 1st  ',
#  '3. Governement uses its fiscal tools i.e. taxes and subsidies to promote '
#  'social  ',
#  '5. During recession or deflation, government can increase its expenditure '
#  'and  ',
#  '6. During inflation, government reduces its expenditure and increases its '
#  'receipts  ',
#  'i.e government may enforce increase in tax and reduction in subsidies to  ',
#  '4. Government budget can be an ef fective tool to ensure economic growth in '
#  'the  ',
#  'infrastructural base of the economy like government increasing its '
#  'expenditure  ',
#  'Fiscal Discipline refers to ideal balance between the government expenditure '
#  'and  ',
#  'Deficit Budget  - When government expenditure is more than receipts',
#  '1. Fiscal Deficit refers to excess of total expenditure over total '
#  'receipts  ',
#  'a. Deficit Financing  - The Central bank may finance the government  ',
#  'from the Central Bank i.e RBI against securities or Treasury Bills.',
#  'b. Borrowings from the Public - The Budget Deficit can be financed  ',
#  'supervises, regulates and controls the activities of the commercial banks '
#  'and other  ',
#  'In India, RBI is the Central Bank of the country .',
#  'It is the primary function of the Central bank to issue the currency .',
#  'Central Bank is like banker , agent and adviser to the government.',
#  'Sometimes government borrows money to finance its Budget Deficit.',
#  'As an Adviser -  The Central Bank acts as an adviser to the government  ',
#  'Controlling of money supply and credit is another important function of RBI',
#  'Custodian of Cash Reserves of commercial banks (CRR)  - ',
#  'deposits known as Cash Reserve Ratio (CRR) with the Central Bank.',
#  'It enables the Central Bank to control credit creation done by the  ',
#  'commercial banks by changing the Cash Reserve Requirement.',
#  'A commercial bank can borrow from the Central  ',
#  'Clearing House - As Central Bank holds the cash reserves of all the  ',
#  '14As a supervisor , Central Bank regulates and controls the commercial '
#  'banks.',
#  'The Central bank is empowered to regulate the money supply in the economy '
#  'through  ',
#  'It is the policy adopted by the Central Bank in the direction of credit  ',
#  'advances long-term loans to the commercial banks.',
#  'On the other hand, the rate at which commercial bank advances loans to  ',
#  'An increase in Bank Rate increases the cost of borrowings from the Central  ',
#  'It forces the commercial bank to increase their lending rates which  ',
#  'A decrease in Bank Rate by RBI reduces the cost of borrowings for '
#  'commercial  ',
#  'to take loans so it increases the ability of commercial banks to create '
#  'credit i.e.',
#  'The Central Bank advances loan against approved or eligible  ',
#  'commercial banks can deposit their surplus funds with the Central Bank '
#  '(for  ',
#  'depositing their funds with the Central Bank.',
#  'depositing their funds with the Central Bank.',
#  'government securities in the open market by the Central Bank.',
#  'the commercial banks which in turn reduces the credit creating capacity of  ',
#  'these banks, thus selling of securities reduces the availability of '
#  'credit/money  ',
#  'reserves of the commercial bank which in turn increases the credit '
#  'creation  ',
#  'deflation, Central Bank expands the credit with the purchase of securities.',
#  'Commercial banks are required to maintain certain reserves as a matter of '
#  'law  ',
#  'Commercial banks are required to maintain two types of  ',
#  '16Cash Reserve Ratio (CRR) - Every commercial bank is required to keep a  ',
#  'An increase in CRR reduces the cash reserves of the commercial banks  ',
#  'An increase in SLR reduces the credit creation capacity of the bank.',
#  'Requirement, the Central Bank can expand or contract the credit creating  ',
#  'operate with the general monetary policy of the Central Bank.',
#  '3. Credit Rationing - In this method, the Central Bank can give directions '
#  'to the  ',
#  'The rate of interest at which commercial bank accepts deposit is known as  ',
#  'In India, scheduled commercial banks are fo three types  ',
#  'Functions of Commercial Banks',
#  'There can be following types of functions of commercial banks : ',
#  'The primary or basic function of commercial bank is to accept deposit  ',
#  'Commercial banks accepts following types of deposits : ',
#  'Different types of loans and advances made by commercial banks are : ']

# %%
print(summarize(fulltext, word_count=150))
# Out:
# ('receipts and estimated expenditures of the government during a fiscal year '
#  '(from 1st  \n'
#  '6. During inflation, government reduces its expenditure and increases its '
#  'receipts  \n'
#  'Deficit Budget  - When government expenditure is more than receipts\n'
#  'a. Deficit Financing  - The Central bank may finance the government  \n'
#  'Sometimes government borrows money to finance its Budget Deficit.\n'
#  'deposits known as Cash Reserve Ratio (CRR) with the Central Bank.\n'
#  'It enables the Central Bank to control credit creation done by the  \n'
#  'A commercial bank can borrow from the Central  \n'
#  'A decrease in Bank Rate by RBI reduces the cost of borrowings for '
#  'commercial  \n'
#  'to take loans so it increases the ability of commercial banks to create '
#  'credit i.e.\n'
#  'government securities in the open market by the Central Bank.\n'
#  'reserves of the commercial bank which in turn increases the credit '
#  'creation  \n'
#  'An increase in CRR reduces the cash reserves of the commercial banks  ')

# %%
print(keywords(fulltext))
# Out:
# ('bank\n'
#  'banking\n'
#  'government\n'
#  'governments\n'
#  'commercial banks\n'
#  'governement uses\n'
#  'macroeconomics\n'
#  'macroeconomic\n'
#  'budget\n'
#  'economics\n'
#  'economic\n'
#  'general\n'
#  'generates\n'
#  'generation\n'
#  'generally\n'
#  'generations\n'
#  'receipts\n'
#  'receipt\n'
#  'taxes\n'
#  'tax\n'
#  'deficit\n'
#  'examples\n'
#  'example\n'
#  'rate\n'
#  'like\n'
#  'fiscal\n'
#  'borrowing\n'
#  'borrowings\n'
#  'borrow\n'
#  'borrows\n'
#  'borrowers\n'
#  'borrower\n'
#  'main credit\n'
#  'certain\n'
#  'public\n'
#  'rbi\n'
#  'deposits\n'
#  'deposit\n'
#  'depositing\n'
#  'deposited\n'
#  'function\n'
#  'functions\n'
#  'functioning\n'
#  'period\n'
#  'periodic\n'
#  'income\n'
#  'securities\n'
#  'security\n'
#  'reducing\n'
#  'reduce\n'
#  'reduces\n'
#  'reduced\n'
#  'financial\n'
#  'money\n'
#  'loans\n'
#  'loan\n'
#  'foreign\n'
#  'lending rates\n'
#  'controls\n'
#  'control\n'
#  'controller\n'
#  'controlling\n'
#  'controlled\n'
#  'increasing\n'
#  'increase\n'
#  'increases\n'
#  'increased\n'
#  'direct\n'
#  'direction\n'
#  'directions\n'
#  'policies\n'
#  'policy\n'
#  'central\n'
#  'sector\n'
#  'sectors\n'
#  'called\n'
#  'expenditures\n'
#  'expenditure\n'
#  'margin\n'
#  'margins\n'
#  'reserve\n'
#  'reserves\n'
#  'revenue\n'
#  'total\n'
#  'capital\n'
#  'higher\n'
#  'provided\n'
#  'providing\n'
#  'provident\n'
#  'keynes\n'
#  'types\n'
#  'type\n'
#  'create\n'
#  'creates\n'
#  'currency\n'
#  'currencies\n'
#  'investments\n'
#  'investment\n'
#  'india\n'
#  'deflation\n'
#  'inflation\n'
#  'price\n'
#  'crr\n'
#  'legal\n'
#  'source\n'
#  'sources\n'
#  'lends\n'
#  'lend\n'
#  'makes\n'
#  'making\n'
#  'market\n'
#  'word\n'
#  'words\n'
#  'dif ferent\n'
#  'scheduled\n'
#  'schedule\n'
#  'provide free services\n'
#  'service\n'
#  'small\n'
#  'requirement\n'
#  'requirements\n'
#  'required\n'
#  'creating capacity\n'
#  'cash\n'
#  'enterprises\n'
#  'savings\n'
#  'saves\n'
#  'saving\n'
#  'save\n'
#  'objectives\n'
#  'objective\n'
#  'production\n'
#  'productive\n'
#  'growth\n'
#  'liquidity\n'
#  'liquid\n'
#  'lead\n'
#  'leads\n'
#  'short\n'
#  'measures\n'
#  'measure\n'
#  'burden\n'
#  'social\n'
#  'education\n'
#  'ragnar\n'
#  'payment\n'
#  'payments\n'
#  'century\n'
#  'settle\n'
#  'food\n'
#  'assets\n'
#  'finance\n'
#  'financing\n'
#  'financed\n'
#  'profit\n'
#  'profits\n'
#  'cycle\n'
#  'debt\n'
#  'post\n'
#  'specific\n'
#  'adopts\n'
#  'adopted\n'
#  'notes\n'
#  'note\n'
#  'socially useful\n'
#  'advances\n'
#  'advancing\n'
#  'instrument\n'
#  'instruments\n'
#  'primary\n'
#  'suf ficient\n'
#  'issuing\n'
#  'issue\n'
#  'issued\n'
#  'issues\n'
#  'classical\n'
#  'stability\n'
#  'ratio\n'
#  'ratios\n'
#  'reverse\n'
#  'termed\n'
#  'term\n'
#  'qualitative\n'
#  'balance\n'
#  'balanced\n'
#  'economy\n'
#  'economies\n'
#  'level\n'
#  'levels\n'
#  'implies\n'
#  'slr\n'
#  'capacities\n'
#  'branch\n'
#  'order\n'
#  'promote\n'
#  'promoters\n'
#  'limited\n'
#  'limit\n'
#  'use')

# %%
print(keywords(fulltext, lemmatize=True))
# Out:
# ('governments\n'
#  'commercial banks\n'
#  'macroeconomic\n'
#  'budget\n'
#  'economic\n'
#  'generations\n'
#  'receipt\n'
#  'tax\n'
#  'deficit\n'
#  'example\n'
#  'rates\n'
#  'like\n'
#  'fiscal\n'
#  'borrower\n'
#  'main credit\n'
#  'certain\n'
#  'public\n'
#  'rbi\n'
#  'deposited\n'
#  'functioning\n'
#  'periodic\n'
#  'income\n'
#  'security\n'
#  'reduced\n'
#  'financial\n'
#  'money\n'
#  'loan\n'
#  'foreign\n'
#  'controlled\n'
#  'increased\n'
#  'directions\n'
#  'policy\n'
#  'central\n'
#  'sectors\n'
#  'called\n'
#  'expenditure\n'
#  'margins\n'
#  'reserves\n'
#  'revenue\n'
#  'total\n'
#  'capital\n'
#  'higher\n'
#  'provident\n'
#  'keynes\n'
#  'type\n'
#  'currencies\n'
#  'investment\n'
#  'india\n'
#  'deflation\n'
#  'inflation\n'
#  'price\n'
#  'crr\n'
#  'legal\n'
#  'sources\n'
#  'lend\n'
#  'making\n'
#  'market\n'
#  'words\n'
#  'dif ferent\n'
#  'schedule\n'
#  'service\n'
#  'small\n'
#  'required\n'
#  'creating capacity\n'
#  'cash\n'
#  'enterprises\n'
#  'save\n'
#  'objective\n'
#  'productive\n'
#  'growth\n'
#  'liquid\n'
#  'leads\n'
#  'short\n'
#  'measure\n'
#  'burden\n'
#  'ragnar\n'
#  'settle\n'
#  'century\n'
#  'food\n'
#  'payments\n'
#  'education\n'
#  'assets\n'
#  'financed\n'
#  'profits\n'
#  'cycle\n'
#  'debt\n'
#  'post\n'
#  'specific\n'
#  'adopted\n'
#  'note\n'
#  'socially useful\n'
#  'advancing\n'
#  'instruments\n'
#  'primary\n'
#  'suf ficient\n'
#  'issues\n'
#  'classical\n'
#  'stability\n'
#  'free\n'
#  'ratios\n'
#  'reverse\n'
#  'term\n'
#  'qualitative\n'
#  'balanced\n'
#  'economies\n'
#  'levels\n'
#  'implies\n'
#  'slr\n'
#  'branch\n'
#  'order\n'
#  'promoters\n'
#  'limit')

# %%
print(keywords(fulltext, split=True))
# Out:
# ['bank',
#  'banking',
#  'government',
#  'governments',
#  'commercial banks',
#  'governement uses',
#  'macroeconomics',
#  'macroeconomic',
#  'budget',
#  'economics',
#  'economic',
#  'general',
#  'generates',
#  'generation',
#  'generally',
#  'generations',
#  'receipts',
#  'receipt',
#  'taxes',
#  'tax',
#  'deficit',
#  'examples',
#  'example',
#  'rate',
#  'like',
#  'fiscal',
#  'borrowing',
#  'borrowings',
#  'borrow',
#  'borrows',
#  'borrowers',
#  'borrower',
#  'main credit',
#  'certain',
#  'public',
#  'rbi',
#  'deposits',
#  'deposit',
#  'depositing',
#  'deposited',
#  'function',
#  'functions',
#  'functioning',
#  'period',
#  'periodic',
#  'income',
#  'securities',
#  'security',
#  'reducing',
#  'reduce',
#  'reduces',
#  'reduced',
#  'financial',
#  'money',
#  'loans',
#  'loan',
#  'foreign',
#  'lending rates',
#  'controls',
#  'control',
#  'controller',
#  'controlling',
#  'controlled',
#  'increasing',
#  'increase',
#  'increases',
#  'increased',
#  'direct',
#  'direction',
#  'directions',
#  'policies',
#  'policy',
#  'central',
#  'sector',
#  'sectors',
#  'called',
#  'expenditures',
#  'expenditure',
#  'margin',
#  'margins',
#  'reserve',
#  'reserves',
#  'revenue',
#  'total',
#  'capital',
#  'higher',
#  'provided',
#  'providing',
#  'provident',
#  'keynes',
#  'types',
#  'type',
#  'create',
#  'creates',
#  'currency',
#  'currencies',
#  'investments',
#  'investment',
#  'india',
#  'deflation',
#  'inflation',
#  'price',
#  'crr',
#  'legal',
#  'source',
#  'sources',
#  'lends',
#  'lend',
#  'makes',
#  'making',
#  'market',
#  'word',
#  'words',
#  'dif ferent',
#  'scheduled',
#  'schedule',
#  'provide free services',
#  'service',
#  'small',
#  'requirement',
#  'requirements',
#  'required',
#  'creating capacity',
#  'cash',
#  'enterprises',
#  'savings',
#  'saves',
#  'saving',
#  'save',
#  'objectives',
#  'objective',
#  'production',
#  'productive',
#  'growth',
#  'liquidity',
#  'liquid',
#  'lead',
#  'leads',
#  'short',
#  'measures',
#  'measure',
#  'burden',
#  'social',
#  'food',
#  'payment',
#  'payments',
#  'century',
#  'settle',
#  'ragnar',
#  'education',
#  'assets',
#  'finance',
#  'financing',
#  'financed',
#  'profit',
#  'profits',
#  'cycle',
#  'debt',
#  'post',
#  'specific',
#  'adopts',
#  'adopted',
#  'notes',
#  'note',
#  'socially useful',
#  'advances',
#  'advancing',
#  'instrument',
#  'instruments',
#  'primary',
#  'suf ficient',
#  'issuing',
#  'issue',
#  'issued',
#  'issues',
#  'classical',
#  'stability',
#  'ratio',
#  'ratios',
#  'reverse',
#  'termed',
#  'term',
#  'qualitative',
#  'balance',
#  'balanced',
#  'economy',
#  'economies',
#  'level',
#  'levels',
#  'implies',
#  'slr',
#  'capacities',
#  'branch',
#  'order',
#  'promote',
#  'promoters',
#  'limited',
#  'limit',
#  'use']

# %%
print(keywords(fulltext, ratio=0.1))
# Out:
# ('bank\n'
#  'banking\n'
#  'government\n'
#  'governement\n'
#  'governments\n'
#  'commercial banks\n'
#  'credit\n'
#  'macroeconomics\n'
#  'macroeconomic\n'
#  'budget\n'
#  'economics\n'
#  'economic\n'
#  'general\n'
#  'generates\n'
#  'generation\n'
#  'generally\n'
#  'generations\n'
#  'receipts\n'
#  'receipt\n'
#  'taxes\n'
#  'tax\n'
#  'deficit\n'
#  'examples\n'
#  'example\n'
#  'rate\n'
#  'like\n'
#  'fiscal\n'
#  'borrowing\n'
#  'borrowings\n'
#  'borrow\n'
#  'borrows\n'
#  'borrowers\n'
#  'borrower\n'
#  'certain\n'
#  'public\n'
#  'rbi\n'
#  'deposits\n'
#  'deposit\n'
#  'depositing\n'
#  'deposited\n'
#  'function\n'
#  'functions\n'
#  'functioning\n'
#  'period\n'
#  'periodic\n'
#  'income\n'
#  'securities\n'
#  'security\n'
#  'reducing\n'
#  'reduce\n'
#  'reduces\n'
#  'reduced\n'
#  'financial\n'
#  'money\n'
#  'loans\n'
#  'loan\n'
#  'foreign\n'
#  'lending rates\n'
#  'controls\n'
#  'control\n'
#  'controller\n'
#  'controlling\n'
#  'controlled\n'
#  'increasing\n'
#  'increase\n'
#  'increases\n'
#  'increased\n'
#  'direct\n'
#  'direction\n'
#  'directions\n'
#  'policies\n'
#  'policy\n'
#  'central\n'
#  'sector\n'
#  'sectors\n'
#  'called\n'
#  'expenditures\n'
#  'expenditure\n'
#  'margin\n'
#  'margins\n'
#  'reserve\n'
#  'reserves\n'
#  'revenue\n'
#  'total\n'
#  'dif\n'
#  'capital\n'
#  'higher\n'
#  'provide\n'
#  'provided\n'
#  'providing\n'
#  'provident\n'
#  'keynes\n'
#  'types\n'
#  'type\n'
#  'create\n'
#  'creates\n'
#  'creating\n'
#  'currency\n'
#  'currencies\n'
#  'investments\n'
#  'investment\n'
#  'india\n'
#  'deflation\n'
#  'inflation\n'
#  'price\n'
#  'crr\n'
#  'legal\n'
#  'source\n'
#  'sources\n'
#  'lends\n'
#  'lend\n'
#  'makes\n'
#  'making')
