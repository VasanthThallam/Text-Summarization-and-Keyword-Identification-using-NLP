# %% [markdown]
# Text Summarization
# ==================
#
#
# Shows how to summarize text by extracting the most important sentences from it.
#
# This module automatically summarizes the given text by extracting one or more important sentences from the text. Similarly, it can also extract keywords.
#
# This summarizer is based on the "TextRank" algorithm.
#
#
#
# **Extractive summarization** involves selecting and combining crucial sentences, phrases, or words from an original text to create a shorter version. Generally, the extracted information remains unchanged from the input. (Relative order of sentences may change but every sentence is taken from input)

# %%
from pprint import pprint as print
from gensim.summarization import summarize

# %% [markdown]
# `gensim` is a robust, efficient open-source python library which is designed for Natural Language Processing(NLP), topic modeling, similarity retrieval using corpora and document indexing etc..
#
# `gensim.summarization.summarize` this function provided by the `gensim` library,
#
#
# This function is important for summarizing text. It uses a modified version of the TextRank algorithm to select the important sentences from the input text and create a summary that contain the most important information.
#
# **TextRank** is an unsupervised, graph-based ranking algorithm used for Natural Language Processing tasks, like extracting keywords from text or generating summaries.Its works by assuming the text like a graph with nodes as words or sentences and the edges indicate how the nodes relate to each other.TextRank uses PageRank to determine the most important nodes which are used to generate summaries or highlight important sentences in texts.

# %% [markdown]
# Let's consider this example for better understanding.

# %% [markdown]
# Extractive summarization is a text summarization technique based on identifying and separating the primary sentences or phrases in the source text to create summary. The extractive summarization systems employ statistical algorithms and linguistic analysis to assess word frequency, sentence position, and keyword occurrence to gauge the importance of each type of textual input. The prioritized sentences are then placed together to develop a brief, information summary. The primary benefit of extractive summarization is its simplicity and the ability for computational deployment. Additionally, the process is relatively straight forward, as the summary is based on the pre-existing text and its extraction. However, in the operational mode, the summaries may lose interpersonal aspects and lack a wholistic context."

# %%
# text = (
#     "Extractive summarization is a text summarization technique based on identifying and separating the primary sentences or phrases in the source text to create summary. The extractive summarization systems employ statistical algorithms and linguistic analysis to assess word frequency, sentence position, and keyword occurrence to gauge the importance of each type of textual input. The prioritized sentences are then placed together to develop a brief, information summary. The primary benefit of extractive summarization is its simplicity and the ability for computational deployment. Additionally, the process is relatively straight forward, as the summary is based on the pre-existing text and its extraction. However, in the operational mode, the summaries may lose interpersonal aspects and lack a wholistic context."
# )
text = input("Enter text: ")
print(text)
# Out:
# ('Extractive summarization is a text summarization technique based on '
#  'identifying and separating the primary sentences or phrases in the source '
#  'text to create summary. The extractive summarization systems employ '
#  'statistical algorithms and linguistic analysis to assess word frequency, '
#  'sentence position, and keyword occurrence to gauge the importance of each '
#  'type of textual input. The prioritized sentences are then placed together to '
#  'develop a brief, information summary. The primary benefit of extractive '
#  'summarization is its simplicity and the ability for computational '
#  'deployment. Additionally, the process is relatively straight forward, as the '
#  'summary is based on the pre-existing text and its extraction. However, in '
#  'the operational mode, the summaries may lose interpersonal aspects and lack '
#  'a wholistic context.')

# %% [markdown]
# When we pass the string data(input text) as an input to the summarize function, the function will process the data and generate a summary based on the input text.

# %%
print(summarize(text))
# Out:
# ('Extractive summarization is a text summarization technique based on '
#  'identifying and separating the primary sentences or phrases in the source '
#  'text to create summary.')

# %% [markdown]
# As we are implementing Extractive summarization, the output generated is not created externally, it just the part of the input text which is most significant among all the sentences.

# %%
print(summarize(text, ratio=0.6))
# Out:
# ('Extractive summarization is a text summarization technique based on '
#  'identifying and separating the primary sentences or phrases in the source '
#  'text to create summary.\n'
#  'The primary benefit of extractive summarization is its simplicity and the '
#  'ability for computational deployment.\n'
#  'Additionally, the process is relatively straight forward, as the summary is '
#  'based on the pre-existing text and its extraction.')

# %%
print(summarize(text, split=True))
# Out:
# ['Extractive summarization is a text summarization technique based on '
#  'identifying and separating the primary sentences or phrases in the source '
#  'text to create summary.']

# %%
print(summarize(text, word_count=50))
# Out:
# ('Extractive summarization is a text summarization technique based on '
#  'identifying and separating the primary sentences or phrases in the source '
#  'text to create summary.\n'
#  'Additionally, the process is relatively straight forward, as the summary is '
#  'based on the pre-existing text and its extraction.')

# %% [markdown]
# Here the summarize function has 2 attributes for each call, i.e; the input text and ratio, split, wordcount respectively. So, each attribute has its own function.
#
# *ratio* controls the length of summary as a fraction of input text.
#
# *split* when set to True, returns the summary as a list of sentences instead of single sentence/string.
#
# *word_count* specifies the maximum number of words in the summary.

# %% [markdown]
# KeyWord Identification
# ==================
#
# As mentioned earlier, this module also supports keyword extraction. Keyword extraction works in the same way as summary generation (i.e. sentence extraction), in that the algorithm tries to find words that are important or seem to be representative of the text as a whole.

# %%
from gensim.summarization import keywords

# %% [markdown]
# `gensim.summarization.keywords` function is used for identification and extracting the words/phrases from the text data.
#
# The gensim keywords module uses Natural Language Processing techniques, like term frequency-inverse document frequency (TF-IDF), to find the most important keywords in a given text.

# %%
print(keywords(text))
# Out:
# ('sentences\n'
#  'sentence\n'
#  'summarization\n'
#  'text\n'
#  'straight\n'
#  'interpersonal\n'
#  'deployment\n'
#  'summary\n'
#  'summaries\n'
#  'information')

# %%
print(keywords(text,  lemmatize=True))
# Out:
# ('sentence\n'
#  'summarization\n'
#  'text\n'
#  'interpersonal\n'
#  'deployment\n'
#  'straight\n'
#  'information\n'
#  'summaries')

# %%
print(keywords(text, split=True))
# Out:
# ['sentences',
#  'sentence',
#  'summarization',
#  'text',
#  'straight',
#  'interpersonal',
#  'deployment',
#  'summary',
#  'information',
#  'summaries']

# %%
print(keywords(text, ratio=0.4))
# Out:
# ('summarization\n'
#  'primary sentences\n'
#  'frequency sentence\n'
#  'text\n'
#  'interpersonal\n'
#  'straight\n'
#  'deployment\n'
#  'summary\n'
#  'summaries\n'
#  'information\n'
#  'word\n'
#  'technique\n'
#  'systems employ statistical\n'
#  'analysis')

# %% [markdown]
# Similarly, in keyword extraction, there are two parameters: input text and lemmatize, split, ratio are also important parameters.
#
# *lemmatize* when set to True, this parameter lemmatizes the keywords.(Lemmatization reduces the given word into its root word)
#
# *split* when set to True, returns the keywords as a list.
#
# *ratio* specifies the number of keywords relative to the number of words in input text.

# %% [markdown]
# Lets take a larger example, **Text file** as input data

# %%
with open('avatar.txt', 'r') as file:
    text1 = file.read()

print(text1)
# Out:
# ("In 2154, humans have depleted Earth's natural resources, leading to a severe "
#  'energy crisis. The Resources Development Administration (RDA) mines a '
#  'valuable mineral Unobtanium on Pandora, a densely forested habitable moon '
#  'orbiting Polyphemus, a fictional gas giant in the Alpha Centauri star '
#  'system. Pandora, whose atmosphere is poisonous to humans, is inhabited by '
#  "the Na'Vi, a species of 10-foot tall (3.0 m), blue-skinned, sapient "
#  'humanoids that live in harmony with nature and worship a mother goddess '
#  'named Eywa. It takes 6 years to get from Earth to Pandora in cryogenic '
#  'sleep.\n'
#  '\n'
#  "To explore Pandora's biosphere, scientists use Na'Vi-human hybrids (grown "
#  'from human + native DNA) called "avatars", operated by genetically matched '
#  'humans. Jake Sully (Sam Worthington), a paraplegic former Marine, replaces '
#  'his deceased identical twin brother as an operator of one. Jake was leading '
#  'a purposeless life on Earth and was contacted by RDA when his brother died. '
#  'his brother represented a significant investment by RDA, since the avatars '
#  'are linked to the human DNA/genome. Since Jake is a twin, he has the same '
#  'exact DNA as his brother and can take his place in the Avatar program. Dr. '
#  'Grace Augustine (Sigourney Weaver), head of the Avatar Program, considers '
#  'Sully an inadequate replacement (as she considers Jake a mere Jarhead) but '
#  "accepts his assignment as a bodyguard for excursions deep into Na'Vi "
#  'territory.\n'
#  '\n'
#  'Tracy (Michelle Rodriguez) is the pilot assigned to Grace and her team of '
#  "Na'Vis. While escorting the avatars of Grace and fellow scientist Dr. Norm "
#  "Spellman (Joel David Moore), Jake's avatar is attacked by a Thanator (while "
#  'they were visiting the school that Grace was operating to teach the '
#  'Omaticaya. She also does test on tree roots and is developing a theory that '
#  'all living things on the planet are somehow attached and connected to each '
#  'other) and flees into the forest, where he is rescued by Neytiri (Zoe '
#  "Saldana), a female Na'Vi. Witnessing an auspicious sign (Seeds of the sacred "
#  'tree land on Jake, covering him. Something she later calls Eywa), she takes '
#  "him to her clan. The Na'Vi respect all living things and Neytiri is angry "
#  "because to save Jake she had to kill many native species. Neytiri's mother "
#  "Mo'At (CCH Pounder), the clan's spiritual leader, orders her daughter to "
#  'initiate Jake into their society. Grace and Tracy return to base camp, as '
#  'they are not allowed to run night ops as per protocol. The Omaticaya (the '
#  "Na'Vi clan has its HQ in the Hometree)\n"
#  '\n'
#  "Colonel Miles Quaritch (Stephen Lang), head of RDA's private security force, "
#  'promises Jake that the company will restore his legs if he gathers '
#  "information about the Na'Vi and the clan's gathering place, a giant tree "
#  'called Hometree, which stands above the richest deposit of Unobtanium in the '
#  "area. Jake has 3 months to convince the Na'Vi to move as that's when the "
#  'bulldozers get to the tree. Jake learns that Neytiri and her sister Slywanin '
#  "studied at Grace's school. Sylwanin is dead. When Grace learns of Jake's "
#  'work for Miles (she sees him explaining the inner structure of the Hometree '
#  'to Miles and Parker), she transfers herself, Jake, and Norm to an outpost. '
#  'Over the following three months, Jake and Neytiri fall in love as Jake grows '
#  'to sympathize with the natives. Neytiri also teaches Jake about Eywa, the '
#  'network of energy that flows through all living things. Grace also reveals '
#  'that one day the Omaticaya destroyed a bulldozer and hid inside her school. '
#  "Miles's troopers attacked them and Sylwanin died. The Na'Vi never returned. "
#  "They wanted Grace to protect the Na'Vi.\n"
#  '\n'
#  'After Jake is initiated into the tribe (he even captures a banshee/Ikran (a '
#  'flying predator kind of creature), after Neytiri deems him ready to be a '
#  'warrior. She even takes Jake to the tree of souls, their most sacred site), '
#  'he and Neytiri choose each other as mates. Jake and Neytiri escape an attack '
#  'from Toruk, the biggest banshee in the sky. Rider of the Toruk is called '
#  'Toruk Macto. Soon afterward, Jake reveals his change of allegiance when he '
#  "attempts to disable a bulldozer that threatens to destroy a sacred Na'Vi "
#  "site. When Quaritch shows a video recording of Jake's attack on the "
#  'bulldozer to Administrator Parker Selfridge (Giovanni Ribisi), and another '
#  "in which Jake admits that the Na'Vi will never abandon Hometree, Selfridge "
#  'orders Hometree destroyed (this was after the Omaticaya retaliated and '
#  'destroyed the bulldozers and killed 6 humans in the process. Grace thinks '
#  'the bulldozers were specifically sent to evoke a response and use that as an '
#  'excuse for war)\n'
#  '\n'
#  "Despite Grace's argument that destroying Hometree could damage the "
#  'biological neural network native to Pandora, Selfridge gives Jake and Grace '
#  "one hour to convince the Na'Vi to evacuate before commencing the attack. "
#  "Jake confesses to the Na'Vi that he was a spy, and they take him and Grace "
#  "captive. Quaritch's men destroy Hometree, killing Neytiri's father (the clan "
#  "chief) and many others. Mo'At frees Jake and Grace, but they are detached "
#  "from their avatars and imprisoned by Quaritch's forces. Pilot Trudy Chacón, "
#  "disgusted by Quaritch's brutality, frees Jake, Grace, and Norm, and airlifts "
#  "them to Grace's outpost, but Grace is shot by Quaritch during the escape. "
#  'Trudy takes the mobile station and hides it near the tree of souls where '
#  'Miles cannot find it as the flux vortex scrambles all radars.\n'
#  '\n'
#  "To regain the Na'Vi's trust, Jake attacks and connects his mind to that of "
#  "Toruk, a dragon-like predator feared and honored by the Na'Vi. Jake finds "
#  'the refugees at the sacred Tree of Souls (the Omaticaya are forced to take '
#  'him seriously due to the power and symbolism of the Toruk) and pleads with '
#  "Mo'At to heal Grace. The clan attempts to transfer Grace from her human body "
#  'into her avatar with the aid of the Tree of Souls, but she dies before the '
#  "process can be completed. Supported by the new chief Tsu'Tey (Laz Alonso), "
#  'Jake unites the clan and tells them to gather all of the clans to battle the '
#  'RDA. Quaritch organizes a preemptive strike against the Tree of Souls, '
#  'believing that its destruction will demoralize the natives. On the eve of '
#  'battle, Jake prays to Eywa, via a neural connection with the Tree of Souls, '
#  "to intercede on behalf of the Na'Vi.\n"
#  '\n'
#  "During the subsequent battle, the Na'Vi suffer heavy casualties, including "
#  "Tsu'Tey and Trudy, but are rescued when Pandoran wildlife unexpectedly join "
#  "the attack and overwhelm the humans, which Neytiri interprets as Eywa's "
#  "answer to Jake's prayer. Jake destroys a makeshift bomber before it can "
#  'reach the Tree of Souls; Quaritch, wearing an AMP suit, escapes from his own '
#  "damaged aircraft and breaks open the avatar link unit containing Jake's "
#  "human body, exposing it to Pandora's poisonous atmosphere. Quaritch prepares "
#  "to slit the throat of Jake's avatar, but Neytiri kills Quaritch and saves "
#  'Jake from suffocation, seeing his human form for the first time.\n'
#  '\n'
#  'With the exceptions of Jake, Norm and a select few others, all humans are '
#  'expelled from Pandora and sent back to Earth. Jake is permanently '
#  'transferred into his avatar with the aid of the Tree of Souls.')

# %%
print(summarize(text1))
# Out:
# ("To explore Pandora's biosphere, scientists use Na'Vi-human hybrids (grown "
#  'from human + native DNA) called "avatars", operated by genetically matched '
#  'humans.\n'
#  'Tracy (Michelle Rodriguez) is the pilot assigned to Grace and her team of '
#  "Na'Vis. While escorting the avatars of Grace and fellow scientist Dr. Norm "
#  "Spellman (Joel David Moore), Jake's avatar is attacked by a Thanator (while "
#  'they were visiting the school that Grace was operating to teach the '
#  'Omaticaya.\n'
#  "Colonel Miles Quaritch (Stephen Lang), head of RDA's private security force, "
#  'promises Jake that the company will restore his legs if he gathers '
#  "information about the Na'Vi and the clan's gathering place, a giant tree "
#  'called Hometree, which stands above the richest deposit of Unobtanium in the '
#  'area.\n'
#  'She even takes Jake to the tree of souls, their most sacred site), he and '
#  'Neytiri choose each other as mates.\n'
#  "When Quaritch shows a video recording of Jake's attack on the bulldozer to "
#  'Administrator Parker Selfridge (Giovanni Ribisi), and another in which Jake '
#  "admits that the Na'Vi will never abandon Hometree, Selfridge orders Hometree "
#  'destroyed (this was after the Omaticaya retaliated and destroyed the '
#  'bulldozers and killed 6 humans in the process.\n'
#  "Quaritch's men destroy Hometree, killing Neytiri's father (the clan chief) "
#  'and many others.\n'
#  "To regain the Na'Vi's trust, Jake attacks and connects his mind to that of "
#  "Toruk, a dragon-like predator feared and honored by the Na'Vi. Jake finds "
#  'the refugees at the sacred Tree of Souls (the Omaticaya are forced to take '
#  'him seriously due to the power and symbolism of the Toruk) and pleads with '
#  "Mo'At to heal Grace.\n"
#  'The clan attempts to transfer Grace from her human body into her avatar with '
#  'the aid of the Tree of Souls, but she dies before the process can be '
#  'completed.\n'
#  'Jake destroys a makeshift bomber before it can reach the Tree of Souls; '
#  'Quaritch, wearing an AMP suit, escapes from his own damaged aircraft and '
#  "breaks open the avatar link unit containing Jake's human body, exposing it "
#  "to Pandora's poisonous atmosphere.\n"
#  "Quaritch prepares to slit the throat of Jake's avatar, but Neytiri kills "
#  'Quaritch and saves Jake from suffocation, seeing his human form for the '
#  'first time.')

# %%
print(summarize(text1, ratio=0.7))
# Out:
# ("Pandora, whose atmosphere is poisonous to humans, is inhabited by the Na'Vi, "
#  'a species of 10-foot tall (3.0 m), blue-skinned, sapient humanoids that live '
#  'in harmony with nature and worship a mother goddess named Eywa.\n'
#  "To explore Pandora's biosphere, scientists use Na'Vi-human hybrids (grown "
#  'from human + native DNA) called "avatars", operated by genetically matched '
#  'humans.\n'
#  'Jake was leading a purposeless life on Earth and was contacted by RDA when '
#  'his brother died.\n'
#  'his brother represented a significant investment by RDA, since the avatars '
#  'are linked to the human DNA/genome.\n'
#  'Since Jake is a twin, he has the same exact DNA as his brother and can take '
#  'his place in the Avatar program.\n'
#  'Dr. Grace Augustine (Sigourney Weaver), head of the Avatar Program, '
#  'considers Sully an inadequate replacement (as she considers Jake a mere '
#  'Jarhead) but accepts his assignment as a bodyguard for excursions deep into '
#  "Na'Vi territory.\n"
#  'Tracy (Michelle Rodriguez) is the pilot assigned to Grace and her team of '
#  "Na'Vis. While escorting the avatars of Grace and fellow scientist Dr. Norm "
#  "Spellman (Joel David Moore), Jake's avatar is attacked by a Thanator (while "
#  'they were visiting the school that Grace was operating to teach the '
#  'Omaticaya.\n'
#  'She also does test on tree roots and is developing a theory that all living '
#  'things on the planet are somehow attached and connected to each other) and '
#  'flees into the forest, where he is rescued by Neytiri (Zoe Saldana), a '
#  "female Na'Vi. Witnessing an auspicious sign (Seeds of the sacred tree land "
#  'on Jake, covering him.\n'
#  'Something she later calls Eywa), she takes him to her clan.\n'
#  "The Na'Vi respect all living things and Neytiri is angry because to save "
#  'Jake she had to kill many native species.\n'
#  "Neytiri's mother Mo'At (CCH Pounder), the clan's spiritual leader, orders "
#  'her daughter to initiate Jake into their society.\n'
#  'Grace and Tracy return to base camp, as they are not allowed to run night '
#  'ops as per protocol.\n'
#  "Colonel Miles Quaritch (Stephen Lang), head of RDA's private security force, "
#  'promises Jake that the company will restore his legs if he gathers '
#  "information about the Na'Vi and the clan's gathering place, a giant tree "
#  'called Hometree, which stands above the richest deposit of Unobtanium in the '
#  'area.\n'
#  "Jake learns that Neytiri and her sister Slywanin studied at Grace's school.\n"
#  "When Grace learns of Jake's work for Miles (she sees him explaining the "
#  'inner structure of the Hometree to Miles and Parker), she transfers herself, '
#  'Jake, and Norm to an outpost.\n'
#  'Over the following three months, Jake and Neytiri fall in love as Jake grows '
#  'to sympathize with the natives.\n'
#  'Neytiri also teaches Jake about Eywa, the network of energy that flows '
#  'through all living things.\n'
#  'Grace also reveals that one day the Omaticaya destroyed a bulldozer and hid '
#  'inside her school.\n'
#  "Miles's troopers attacked them and Sylwanin died.\n"
#  'She even takes Jake to the tree of souls, their most sacred site), he and '
#  'Neytiri choose each other as mates.\n'
#  'Jake and Neytiri escape an attack from Toruk, the biggest banshee in the '
#  'sky.\n'
#  "When Quaritch shows a video recording of Jake's attack on the bulldozer to "
#  'Administrator Parker Selfridge (Giovanni Ribisi), and another in which Jake '
#  "admits that the Na'Vi will never abandon Hometree, Selfridge orders Hometree "
#  'destroyed (this was after the Omaticaya retaliated and destroyed the '
#  'bulldozers and killed 6 humans in the process.\n'
#  "Despite Grace's argument that destroying Hometree could damage the "
#  'biological neural network native to Pandora, Selfridge gives Jake and Grace '
#  "one hour to convince the Na'Vi to evacuate before commencing the attack.\n"
#  "Quaritch's men destroy Hometree, killing Neytiri's father (the clan chief) "
#  'and many others.\n'
#  "Mo'At frees Jake and Grace, but they are detached from their avatars and "
#  "imprisoned by Quaritch's forces.\n"
#  'Trudy takes the mobile station and hides it near the tree of souls where '
#  'Miles cannot find it as the flux vortex scrambles all radars.\n'
#  "To regain the Na'Vi's trust, Jake attacks and connects his mind to that of "
#  "Toruk, a dragon-like predator feared and honored by the Na'Vi. Jake finds "
#  'the refugees at the sacred Tree of Souls (the Omaticaya are forced to take '
#  'him seriously due to the power and symbolism of the Toruk) and pleads with '
#  "Mo'At to heal Grace.\n"
#  'The clan attempts to transfer Grace from her human body into her avatar with '
#  'the aid of the Tree of Souls, but she dies before the process can be '
#  'completed.\n'
#  'Quaritch organizes a preemptive strike against the Tree of Souls, believing '
#  'that its destruction will demoralize the natives.\n'
#  'On the eve of battle, Jake prays to Eywa, via a neural connection with the '
#  "Tree of Souls, to intercede on behalf of the Na'Vi.\n"
#  "During the subsequent battle, the Na'Vi suffer heavy casualties, including "
#  "Tsu'Tey and Trudy, but are rescued when Pandoran wildlife unexpectedly join "
#  "the attack and overwhelm the humans, which Neytiri interprets as Eywa's "
#  "answer to Jake's prayer.\n"
#  'Jake destroys a makeshift bomber before it can reach the Tree of Souls; '
#  'Quaritch, wearing an AMP suit, escapes from his own damaged aircraft and '
#  "breaks open the avatar link unit containing Jake's human body, exposing it "
#  "to Pandora's poisonous atmosphere.\n"
#  "Quaritch prepares to slit the throat of Jake's avatar, but Neytiri kills "
#  'Quaritch and saves Jake from suffocation, seeing his human form for the '
#  'first time.\n'
#  'With the exceptions of Jake, Norm and a select few others, all humans are '
#  'expelled from Pandora and sent back to Earth.\n'
#  'Jake is permanently transferred into his avatar with the aid of the Tree of '
#  'Souls.')

# %%
print(summarize(text1, split=True))
# Out:
# ["To explore Pandora's biosphere, scientists use Na'Vi-human hybrids (grown "
#  'from human + native DNA) called "avatars", operated by genetically matched '
#  'humans.',
#  'Tracy (Michelle Rodriguez) is the pilot assigned to Grace and her team of '
#  "Na'Vis. While escorting the avatars of Grace and fellow scientist Dr. Norm "
#  "Spellman (Joel David Moore), Jake's avatar is attacked by a Thanator (while "
#  'they were visiting the school that Grace was operating to teach the '
#  'Omaticaya.',
#  "Colonel Miles Quaritch (Stephen Lang), head of RDA's private security force, "
#  'promises Jake that the company will restore his legs if he gathers '
#  "information about the Na'Vi and the clan's gathering place, a giant tree "
#  'called Hometree, which stands above the richest deposit of Unobtanium in the '
#  'area.',
#  'She even takes Jake to the tree of souls, their most sacred site), he and '
#  'Neytiri choose each other as mates.',
#  "When Quaritch shows a video recording of Jake's attack on the bulldozer to "
#  'Administrator Parker Selfridge (Giovanni Ribisi), and another in which Jake '
#  "admits that the Na'Vi will never abandon Hometree, Selfridge orders Hometree "
#  'destroyed (this was after the Omaticaya retaliated and destroyed the '
#  'bulldozers and killed 6 humans in the process.',
#  "Quaritch's men destroy Hometree, killing Neytiri's father (the clan chief) "
#  'and many others.',
#  "To regain the Na'Vi's trust, Jake attacks and connects his mind to that of "
#  "Toruk, a dragon-like predator feared and honored by the Na'Vi. Jake finds "
#  'the refugees at the sacred Tree of Souls (the Omaticaya are forced to take '
#  'him seriously due to the power and symbolism of the Toruk) and pleads with '
#  "Mo'At to heal Grace.",
#  'The clan attempts to transfer Grace from her human body into her avatar with '
#  'the aid of the Tree of Souls, but she dies before the process can be '
#  'completed.',
#  'Jake destroys a makeshift bomber before it can reach the Tree of Souls; '
#  'Quaritch, wearing an AMP suit, escapes from his own damaged aircraft and '
#  "breaks open the avatar link unit containing Jake's human body, exposing it "
#  "to Pandora's poisonous atmosphere.",
#  "Quaritch prepares to slit the throat of Jake's avatar, but Neytiri kills "
#  'Quaritch and saves Jake from suffocation, seeing his human form for the '
#  'first time.']

# %%
print(summarize(text1, word_count=100))
# Out:
# ("Colonel Miles Quaritch (Stephen Lang), head of RDA's private security force, "
#  'promises Jake that the company will restore his legs if he gathers '
#  "information about the Na'Vi and the clan's gathering place, a giant tree "
#  'called Hometree, which stands above the richest deposit of Unobtanium in the '
#  'area.\n'
#  'The clan attempts to transfer Grace from her human body into her avatar with '
#  'the aid of the Tree of Souls, but she dies before the process can be '
#  'completed.\n'
#  'Jake destroys a makeshift bomber before it can reach the Tree of Souls; '
#  'Quaritch, wearing an AMP suit, escapes from his own damaged aircraft and '
#  "breaks open the avatar link unit containing Jake's human body, exposing it "
#  "to Pandora's poisonous atmosphere.")

# %%
print(keywords(text1))
# Out:
# ('jake\n'
#  'grace\n'
#  'quaritch\n'
#  'neytiri\n'
#  'humans\n'
#  'human\n'
#  'calls\n'
#  'hometree\n'
#  'tree\n'
#  'selfridge\n'
#  'predator\n'
#  'dna called\n'
#  'scientists\n'
#  'scientist\n'
#  'native\n'
#  'natives\n'
#  'tracy\n'
#  'trudy\n'
#  'destroyed\n'
#  'destroy\n'
#  'destroying\n'
#  'destroys\n'
#  'avatars\n'
#  'avatar\n'
#  'resources\n'
#  'neural\n'
#  'brother\n'
#  'chief\n'
#  'centauri\n'
#  'sign\n'
#  'night\n'
#  'energy\n'
#  'vortex\n'
#  'mineral\n'
#  'banshee\n'
#  'gathers\n'
#  'gathering\n'
#  'gather\n'
#  'replaces\n'
#  'replacement\n'
#  'slywanin\n'
#  'kill\n'
#  'killed\n'
#  'killing\n'
#  'kills\n'
#  'tsu\n'
#  'pilot\n'
#  'force\n'
#  'forces\n'
#  'forced\n'
#  'sapient\n'
#  'wildlife unexpectedly\n'
#  'rda\n'
#  'administration\n'
#  'administrator\n'
#  'takes\n'
#  'escape\n'
#  'escapes\n'
#  'michelle\n'
#  'sully\n'
#  'miles\n'
#  'forest\n'
#  'orders\n'
#  'forested habitable moon orbiting\n'
#  'considers\n'
#  'unites\n'
#  'unit')

# %%
print(keywords(text1, lemmatize=True))
# Out:
# ('jake\n'
#  'grace\n'
#  'quaritch\n'
#  'neytiri\n'
#  'human\n'
#  'calls\n'
#  'hometree\n'
#  'tree\n'
#  'selfridge\n'
#  'predator\n'
#  'scientist\n'
#  'dna\n'
#  'natives\n'
#  'tracy\n'
#  'trudy\n'
#  'destroys\n'
#  'avatar\n'
#  'resources\n'
#  'neural\n'
#  'brother\n'
#  'chief\n'
#  'sign\n'
#  'slywanin\n'
#  'banshee\n'
#  'mineral\n'
#  'centauri\n'
#  'vortex\n'
#  'gather\n'
#  'night\n'
#  'replacement\n'
#  'energy\n'
#  'kills\n'
#  'tsu\n'
#  'pilot\n'
#  'forced\n'
#  'wildlife unexpectedly\n'
#  'sapient\n'
#  'rda\n'
#  'administrator\n'
#  'takes\n'
#  'escapes\n'
#  'michelle\n'
#  'sully\n'
#  'miles\n'
#  'forest\n'
#  'orders\n'
#  'considers\n'
#  'habitable moon orbiting\n'
#  'unit')

# %%
print(keywords(text1, ratio=0.05))
# Out:
# ('jake\n'
#  'grace\n'
#  'quaritch\n'
#  'neytiri\n'
#  'humans\n'
#  'human\n'
#  'calls\n'
#  'hometree\n'
#  'tree\n'
#  'selfridge\n'
#  'predator\n'
#  'dna called\n'
#  'scientists\n'
#  'scientist\n'
#  'native\n'
#  'natives')

# %%
print(keywords(text1, split=True))
# Out:
# ['jake',
#  'grace',
#  'quaritch',
#  'neytiri',
#  'humans',
#  'human',
#  'calls',
#  'hometree',
#  'tree',
#  'selfridge',
#  'predator',
#  'dna called',
#  'scientists',
#  'scientist',
#  'native',
#  'natives',
#  'tracy',
#  'trudy',
#  'destroyed',
#  'destroy',
#  'destroying',
#  'destroys',
#  'avatars',
#  'avatar',
#  'resources',
#  'neural',
#  'brother',
#  'chief',
#  'gathers',
#  'gathering',
#  'gather',
#  'replaces',
#  'replacement',
#  'sign',
#  'night',
#  'banshee',
#  'centauri',
#  'vortex',
#  'mineral',
#  'energy',
#  'slywanin',
#  'kill',
#  'killed',
#  'killing',
#  'kills',
#  'tsu',
#  'pilot',
#  'force',
#  'forces',
#  'forced',
#  'wildlife unexpectedly',
#  'sapient',
#  'rda',
#  'administration',
#  'administrator',
#  'takes',
#  'escape',
#  'escapes',
#  'michelle',
#  'sully',
#  'miles',
#  'forest',
#  'orders',
#  'forested habitable moon orbiting',
#  'considers',
#  'unites',
#  'unit']

# %% [markdown]
# Now we will look into **PDF** files as input data

# %%
import PyPDF2

# %% [markdown]
# `PyPDF2` is a python library, which is used for reading and manuplating the PDF files.
# It has many functionalities in handling PDF files.
# *  Reading PDF files: Read and extract text, and content from PDF files.
# *  Merging PDF files: Combining multiple PDF files into single file.
# *  Splitting PDF files: Split PDF file into multiples files.
# *  Encrypting and Decrypting PDFs: Add passwords to PDF files for security.
# * Rotating Pages: Rotate pages in PDF files.

# %%
reader = PyPDF2.PdfReader('CRED casestudy.pdf')

fulltext=""
for pgnum in range(len(reader.pages)):
    pagecontent=reader.pages[pgnum].extract_text()
    fulltext+=pagecontent

print(fulltext)
# Out:
# (' CRED - CASE STUDY \n'
#  ' Technology-Entrepreneur \n'
#  ' Kunal Shah, a famous Indian entrepreneur , and founder of CRED, was born on '
#  'May 20th, 1983. \n'
#  ' His father owned a small pharmaceutical distribution business in their '
#  'hometown, while his \n'
#  ' mother worked in the insurance sector . Unfortunately , when Kunal was just '
#  '16, his family faced \n'
#  " financial dif ficulties due to his father's struggling business. As a "
#  'result, he had to start working to \n'
#  ' support his family . At the age of 16, he began working in a data entry '
#  'job, where he gained \n'
#  ' valuable experience in data management and analysis. Additionally , he used '
#  'to teach computer \n'
#  ' science to the children in his neighborhood and ran a cyber cafe from his '
#  'house. \n'
#  ' He went to a regular school for his schooling. He wanted to study science '
#  'in college, but due to \n'
#  " his family's financial situation, he ended up earning a Bachelor's degree "
#  'in Philosophy from \n'
#  ' Wilson College in Mumbai.  After completing his degree,  His interest in '
#  'business led him to \n'
#  ' enroll in a part-time MBA course in Consumer Behavior and Marketing at '
#  'Narsee Monjee \n'
#  ' Institute of Management Studies in Mumbai. However , he found that the '
#  'course did not meet his \n'
#  ' expectations, and he eventually dropped out to pursue his interest in '
#  'entrepreneurship. \n'
#  ' Noticing the confusion many Indians faced with credit cards, he identified '
#  'an opportunity to \n'
#  ' simplify credit card management and improve financial control. He founded '
#  'Cred a cutting-edge \n'
#  ' platform that aims to motivate users to make good financial choices and, in '
#  'turn, create a more \n'
#  ' systematic and better life for them. \n'
#  ' The Start-up \n'
#  ' Cred is a FinT ech company that was founded in 2018 with a mission to '
#  'simplify the credit card \n'
#  ' industry in India. The company has been successful in achieving its goal '
#  'and became a unicorn \n'
#  ' on April 6, 2021, making it one of the most valuable fintech startups in '
#  'India. According to the \n'
#  ' latest available information, it has approximately 1600+ employees. \n'
#  ' The platform aims to revolutionize how credit card users interact with '
#  'their finances by of fering \n'
#  ' exclusive privileges and benefits to those with good credit scores, thereby '
#  'creating a flywheel \n'
#  ' effect that encourages more people to make wise financial decisions. \n'
#  ' It is a platform that aims to reward creditworthy individuals while '
#  'addressing trust issues within \n'
#  " Indian society . The company's mission is to create a platform that not "
#  'only facilitates credit card \n'
#  ' bill payments but also of fers rewards for timely payments, thereby '
#  'encouraging financial \n'
#  ' responsibility . Cred’ s founder , Kunal Shah, visualized a platform that '
#  'would privilege those with \n'
#  ' good credit scores, creating a positive feedback loop, that would motivate '
#  'more people to \n'
#  ' improve their creditworthiness. The idea was to of fer rewards to people '
#  'who pay their credit card \n'
#  ' bills on time, thereby incentivizing them to make timely payments and '
#  'improve their credit \n'
#  " scores.  Cred’ s unique approach as a 'T rustT ech' platform, rather than "
#  "just 'Fintech', reflects Shah's belief \n"
#  " that trust is key to economic prosperity .  Cred’ s tagline is '  Suraksha "
#  "Aur Bhar osa Dono  '  .  The \n"
#  ' company aims to build trust between borrowers and lenders, by providing a '
#  'platform that \n'
#  ' rewards creditworthy individuals and incentivizes financial responsibility '
#  '. Overall, Cred’ s \n'
#  ' platform of fers a win-win solution for both borrowers and lenders. It '
#  'rewards borrowers who pay \n'
#  ' their bills on time, while also building trust between borrowers and '
#  'lenders. This approach has \n'
#  ' the potential to transform the credit industry in India and promote '
#  'economic growth and \n'
#  ' prosperity . \n'
#  ' Products and Services: \n'
#  ' Cred is a members-only credit card bill payment platform that rewards its '
#  'members for clearing \n'
#  ' their credit card bills on time. Cred members get access to exclusive '
#  'rewards and experiences \n'
#  ' from premier brands upon clearing their credit card bills on cred. It of '
#  'fers a variety of products \n'
#  ' and services designed to enhance the credit card payment experience.  These '
#  'include: \n'
#  ' ●  Cred Mint  : Launched in August 2021,  in collaboration  with '
#  'RBI-approved P2P \n'
#  ' Non-Banking Financial Company (NBFC), Liquiloans.  Cred Mint is a feature '
#  'that allows \n'
#  ' customers to lend and borrow money from one another using the Cred app. \n'
#  ' ●  Cred Cash  : Launched in 2020, Cred Cash is a flexible  credit line that '
#  'of fers \n'
#  ' pre-approved credit lines of up to Rs 5 lakhs to Cred members without any \n'
#  ' documentation, phone calls, forms, or physical visits. \n'
#  ' ●  Rent Pay  : Launched in April 2020, Rent Pay enables  Cred users to pay '
#  'their monthly \n'
#  ' rent using their credit cards. \n'
#  ' ●  Cred Stor e  : Launched in 2020, Cred Store is an eCommerce  platform '
#  'that of fers more \n'
#  ' than 500 premium brands across a wide range of categories. \n'
#  ' ●  Utility Bill Payments  : Launched in April 2022, this  feature allows '
#  'their users to pay \n'
#  ' their utility bills, including electricity , water bills, and municipal '
#  'tax, through the cred \n'
#  ' app. \n'
#  ' ●  Tap to Pay Featur e  : Launched in February 2022, this  feature enables '
#  'Android users to \n'
#  ' make payments by tapping their smartphones on merchant terminals without '
#  'using \n'
#  ' physical cards or wallets. \n'
#  ' ●  BidBlast  : Launched in December 2022, BidBlast is a  bidding game that '
#  'is exclusive to \n'
#  ' Cred members where they can experience the thrill of bidding without using '
#  'actual \n'
#  ' money by using Cred coins. \n'
#  ' ●  Cred Flash  : Launched in February 2023, Cred Flash  is a feature that '
#  'allows customers to \n'
#  ' make payments using BNPL (Buy Now Pay Later) products within the app and '
#  'across \n'
#  ' more than 500 partner merchants. \n'
#  ' ●  Cred Escapes  : Launched in March 2023, Cred Escapes  is a platform that '
#  'provides \n'
#  ' members with exclusive events, lodging, and premium privileges, including '
#  'spa credits, \n'
#  ' hotel upgrades, and theme park admission. \n'
#  ' ●  P2P Payments  : Launched in April 2023, this feature  allows their '
#  'customers to send \n'
#  ' money to other users through UPI IDs or contact numbers using the P2P '
#  'payment option.  ●  RuPay Cr edit Card-Based Payments  : Launched in August '
#  '2023 in collaboration with \n'
#  ' NPCI, this feature enables customers to make UPI payments using their '
#  'credit cards. \n'
#  ' ●  Fourth Edition of A WP Pr ogram  : Cred launched its fourth version of '
#  'the Accelerated \n'
#  ' Wealth Program in 2023, which allows staf f members to purchase more ESOPs '
#  'with a \n'
#  ' quicker vesting period. \n'
#  ' Target Customers: \n'
#  ' Cred’ s main tar get audience is credit card users in India who make up '
#  'only 1% of the wealthiest \n'
#  " population in the country . The founder's goal is to create a community of "
#  'financially responsible \n'
#  ' and trustworthy individuals who are highly disciplined with their money . \n'
#  ' Investors: \n'
#  ' Cred, a leading fintech company , has established an impressive and diverse '
#  'group of partners and \n'
#  " investors that certify the company's strong position in the industry . As "
#  'of the latest information \n'
#  ' available, Cred has 33 investors as of June 9, 2022, including some of the '
#  'most prominent names \n'
#  ' in the business, such as ● Falcon Edge Capital, ● Coatue Management, ● '
#  'Insight Partners, ● \n'
#  ' DST Global, ● R TP Global, ● T iger Global, ● Greenoaks Capital, ● '
#  'Dragoneer Investment \n'
#  ' Group, and ● Sofina. \n'
#  ' Cred has also made strategic acquisitions, including the purchase of '
#  "kuvera.in . The company's \n"
#  ' investors are a mix of venture capital firms, private equity investors, and '
#  'individual angel \n'
#  ' investors. Among the institutional investors who have supported Cred are '
#  'Ribbit Capital, Peak \n'
#  ' XV Partners, and T iger Global Management, with Qed Innovation Labs being '
#  'the lar gest \n'
#  ' institutional investor . \n'
#  ' Marketing Strategy: \n'
#  ' Cred  uses dif ferent marketing tactics to promote its  brand, such as '
#  'viral marketing or publishing \n'
#  ' finance blogs that reward users with cashback and discounts. Every strategy '
#  'shares two key \n'
#  ' features: uniqueness and the ability to increase brand awareness and '
#  'recall. Cred has partnered \n'
#  ' with the Indian Premier League (IPL) for three seasons as an associate '
#  'sponsor . During IPL \n'
#  ' season, Cred conducts contests, marketing campaigns, and advertisements on '
#  'social media, \n'
#  ' which helps the brand gain more exposure and build trust with the general '
#  'public.  Business model  : \n'
#  ' The business model of Cred consists of four parts: \n'
#  ' ●  Cred App:  It offers easy sign-up and attractive credit card bill of '
#  'fers. \n'
#  ' ●  Businesses that pr ovide offers on the app:  Cred of fers its users many '
#  'exclusive deals \n'
#  ' from various businesses. T o do this, cred partners with businesses to '
#  'provide its \n'
#  ' customers with unique opportunities while also helping the businesses '
#  'become more \n'
#  " visible. It's a win-win situation for everyone involved. \n"
#  ' ●  Users who pay cr edit card bills:  Cred is a simple and user -friendly '
#  'platform for paying \n'
#  ' your credit card bills. It of fers many rewards and benefits, making it a '
#  'better choice than \n'
#  ' other banking apps. cred provides you with a smooth payment experience and '
#  'exclusive \n'
#  ' offers. Many users are so happy with the app that they share it with their '
#  'family and \n'
#  ' friends. \n'
#  ' ●  Cred Mint:  Cred, a lending platform, on Aug 20, 2021,  launched a new '
#  'feature called \n'
#  ' Cred Mint. This feature allows cred users to lend their unused money to '
#  'other trustworthy \n'
#  ' members with a minimum credit score of 750. The lending process is '
#  'transparent and \n'
#  ' lenders can withdraw their money with the accumulated interest whenever '
#  'they want. \n'
#  ' Competitors : \n'
#  ' Cred’ s top competitors are Paytm, Phonepe, GooglePay , Freechar ge, Amazon '
#  'Pay , and \n'
#  ' MobiKwik. \n'
#  ' ●  Paytm  is a fintech app and payments platform headquartered  in Noida, '
#  'Uttar Pradesh, \n'
#  ' India. It was founded in 2010 and is a top competitor of cred. \n'
#  ' ●  PhonePe  , a Bangalore-based digital payment platform founded in 2015, '
#  'competes with \n'
#  ' cred and holds a 50% market share as of December 2022. \n'
#  ' ●  Google Pay  is a digital payment platform created by  Google, which is a '
#  'competitor of \n'
#  ' Cred in terms of mass volume. \n'
#  ' ●  Amazon Pay  , launched in 2007 by Amazon, is a rival  to cred, which now '
#  'of fers diverse \n'
#  ' payment options. \n'
#  ' ●  MobiKwik,  a Gurugram-based fintech company founded  in 2009, is a rival '
#  'of cred that \n'
#  ' offers digital payment options. \n'
#  ' ●  Cred and  Freecharge  are two companies that of fer mobile and utility '
#  'bill payment \n'
#  ' services. Freechar ge was founded by Kunal Shah and Sandeep T andon and is '
#  'now owned \n'
#  ' by Axis Bank. cred competes with Freechar ge in this market.  Vertical '
#  'Expansion : \n'
#  ' Cred is a financial services company that focuses on fintech solutions. It '
#  'of fers a range of \n'
#  ' products designed for credit card users, including rewards for timely '
#  'payments and other \n'
#  ' financial services. In addition to this, Cred has launched a luxury travel '
#  "vertical called 'Escapes,' \n"
#  ' which provides exclusive travel experiences for high-credit-score users. '
#  "The company's market \n"
#  ' coverage reflects its commitment to addressing trust issues in Indian '
#  'society by rewarding good \n'
#  ' financial behavior and expanding into new , premium segments. \n'
#  ' Strengths: \n'
#  ' Cred has a track record of success in fintech, with numerous strengths. '
#  'Here are some key ones: \n'
#  ' ●  Innovative T rustT ech Appr oach:  Cred’ s unique model rewards '
#  'creditworthy \n'
#  ' individuals, fostering a culture of financial responsibility \n'
#  ' ●  Strong Funding and V aluation:  With over $700 million in funding and a '
#  'valuation of $ \n'
#  ' 4.1 billion, cred is well-capitalized \n'
#  ' ●  Large User Base:  Nearly 6 million active users are engaged with the '
#  'cred app, indicating \n'
#  ' a strong market presence. \n'
#  ' ●  Data Security:  Cred prioritizes user data protection, ensuring a safe '
#  'and secure platform. \n'
#  ' ●  Diverse Pr oduct Offerings:  From credit card payments to cred RentPay '
#  'and Cred Cash, \n'
#  ' the company provides a wide range of financial services. \n'
#  ' ●  Talent Management:  Cred invests in skill development and talent '
#  'management, which is \n'
#  ' integral to its growth and innovation. \n'
#  ' Weakness: \n'
#  ' CRED’ s weaknesses, as identified in various analyses, include: \n'
#  ' ●  Payment pr ocessing  : Some users have reported that  payments are '
#  'sometimes not \n'
#  ' processed on time, although successful payments happen more often. \n'
#  " ●  Customer service  : Cred's customer service is limited  to email "
#  'communication, which \n'
#  ' may not be enough for all users. \n'
#  " ●  Data security  : Despite having strong security measures,  Cred's "
#  'private data could still be \n'
#  ' at risk of hacking. \n'
#  " ●  Credit Scor e Requir ement  : Cred's high credit score  requirement may "
#  'prevent low and \n'
#  ' lower -middle-class individuals from using its services.  ●  Loan limit  : '
#  "Cred's loan limit is relatively low , making it more suitable for small \n"
#  ' businesses than lar ger ones. \n'
#  ' ●  Government scrutiny  : There is a risk of governments seeking private '
#  'taxpayer data from \n'
#  ' cred. \n'
#  ' ●  Talent r etention  : Replacing key experts within cred could be costly , '
#  'as few employees \n'
#  ' hold significant knowledge crucial to the company . \n'
#  " ●  Supplier loyalty  : Given cred's history of innovation, suppliers may "
#  'not be very loyal, \n'
#  ' which could af fect the supply chain. \n'
#  ' Uniqueness: \n'
#  ' CRED is unique for several reasons: \n'
#  ' ●  TrustT ech, Not Just Fintech  : Cred’ s founder , Kunal Shah, describes '
#  'the company as a \n'
#  ' TrustT ech platform, focusing on solving trust issues in Indian society , '
#  'which is key to \n'
#  ' economic prosperity . \n'
#  ' ●  Rewards for Cr editworthiness  : It rewards users for  timely credit '
#  'card bill payments, \n'
#  ' incentivizing good financial behavior . \n'
#  ' ●  Exclusive Membership  : Cred is accessible only to individuals  with a '
#  'credit score above \n'
#  ' 750, creating an exclusive community of creditworthy users. \n'
#  ' ●  Diverse Financial Services  : Beyond credit card payments,  Cred of fers '
#  'services like \n'
#  ' RentPay , Cred Cash, and Cred Mint, catering to various financial needs. \n'
#  ' ●  Design and User Experience  : The app’ s design focuses  on ef ficiency '
#  'and creating an \n'
#  ' incentivization layer , providing small moments of joy for users. \n'
#  ' Vision and Mission: \n'
#  ' Cred is a financial technology company that is committed to helping people '
#  'manage their \n'
#  ' finances more ef ficiently and responsibly . \n'
#  " The company's mission revolves around three key objectives: \n"
#  ' ●  Incentivizing good credit behavior \n'
#  ' ●  Simplifying credit card payments \n'
#  ' ●  Promoting financial responsibility . \n'
#  ' Firstly , Cred aims to incentivize good credit behavior by rewarding '
#  'individuals who exhibit \n'
#  ' creditworthy behavior . The company of fers rewards and benefits to users '
#  'who maintain good \n'
#  ' credit scores, make timely payments, and keep their credit utilization low '
#  '. This approach helps  users not only improve their credit scores but also '
#  'develop good financial habits that will benefit \n'
#  ' them in the long term. \n'
#  ' Secondly , Cred simplifies credit card payments by providing a single '
#  'platform that allows users \n'
#  ' to manage all their credit card payments in one place. This eliminates the '
#  'need for users to log in \n'
#  ' to multiple bank accounts to make payments, making the process more '
#  'streamlined and less \n'
#  ' time-consuming. \n'
#  ' Finally , Cred promotes financial responsibility by encouraging users to '
#  'make informed financial \n'
#  ' decisions. The company provides users with educational resources and tools '
#  'that help them \n'
#  ' understand how credit works and how to manage their finances ef fectively . '
#  'By doing so, Cred \n'
#  ' empowers users to take control of their financial futures and build a more '
#  'prosperous and \n'
#  ' inclusive society . \n'
#  " Overall, Cred's mission is to build a community where trust in financial "
#  'transactions is superior \n'
#  ' to all others. By incentivizing good credit behavior , simplifying credit '
#  'card payments, and \n'
#  ' promoting financial responsibility , Cred is helping users take control of '
#  'their finances and create \n'
#  ' a better future for themselves and their communities. \n'
#  ' Risks: \n'
#  ' CRED, like any fintech company , faces several risks. \n'
#  ' ●  One notable risk is associated with its peer -to-peer lending '
#  'platform, \n'
#  ' ●  Cred Mint, where the return rate on investments is not guaranteed, is '
#  'similar to bank \n'
#  ' fixed deposits, posing a risk for investors. \n'
#  ' ●  Additionally , as a fintech platform, Cred is exposed to credit risks '
#  'such as default risk, \n'
#  ' concentration risk, country risk, downgrade risk, and institutional risk. \n'
#  ' Plans: \n'
#  ' Cred has been expanding its services, including the establishment of an '
#  'e-commerce platform, \n'
#  ' the Cred Store, and Cred Pay . These services allow customers to redeem '
#  'reward points and get \n'
#  ' discounts across many online retailers. The company is also exploring '
#  'strategies to cater to \n'
#  ' consumers new to credit by of fering consumer durable loans and checkout '
#  'finance.  VUCA challenges: \n'
#  ' CRED, operating in the dynamic fintech sector , faces VUCA challenges that '
#  'are common to \n'
#  ' modern or ganizations. These include: \n'
#  ' ●  Volatility  : The rapid and unpredictable changes in the market, '
#  'especially in the financial \n'
#  ' sector , can impact Cred’ s operations and strategies. \n'
#  ' ●  Uncertainty  : Economic fluctuations, regulatory changes, and evolving '
#  'consumer \n'
#  ' preferences add to the uncertainty that Cred must navigate. \n'
#  ' ●  Complexity  : The intricate web of interrelated factors, such as global '
#  'economic ties and \n'
#  ' technological advancements, influences Cred’ s decision-making. \n'
#  ' ●  Ambiguity  : The lack of clarity and presence of multiple '
#  'interpretations of information \n'
#  ' can make it challenging for Cred to set a clear strategic direction. \n'
#  ' To address these challenges, Cred needs to be agile, innovative, and '
#  'resilient, adapting its \n'
#  ' strategies to maintain growth and stability in the face of these VUCA '
#  'elements. \n'
#  ' Lessons: \n'
#  ' The journey of Cred of fers several valuable lessons for businesses and '
#  'entrepreneurs: \n'
#  ' ●  Security-First Cultur e  : Cred stresses the importance of prioritizing '
#  'security when \n'
#  ' handling sensitive customer data. Regular training and awareness are '
#  'required to maintain \n'
#  ' high standards. \n'
#  ' ●  Customer -Centric Model  : Cred’ s success is lar gely due to its focus '
#  'on customer needs \n'
#  ' and providing a seamless user experience.  This includes  offering instant '
#  'personal loans \n'
#  ' and credit lines without the need for a lengthy application process. \n'
#  " ●  Innovation  : Constant innovation is crucial for a company's  success. "
#  "Cred's journey \n"
#  ' demonstrates that pioneering new best practices and staying ahead of the '
#  'curve can make \n'
#  ' a significant contribution. \n'
#  ' ●  Trust and T ranspar ency  : Building trust with customers  by being '
#  'transparent about \n'
#  ' business practices and ensuring data privacy can lead to a loyal customer '
#  'base. \n'
#  ' ●  Adaptability  : Adapting to changing market conditions  and customer '
#  'preferences is \n'
#  ' crucial for growth. \n'
#  ' ●  Strategic Fundraising  : Effective fundraising strategies  can provide '
#  'the necessary capital \n'
#  ' for expansion and scaling up operations. \n'
#  ' These lessons from Cred highlight the importance of combining a strong '
#  'security foundation \n'
#  ' with customer -focused innovation and strategic growth initiatives. ')

# %%
print(summarize(fulltext))
# Out:
# ('simplify credit card management and improve financial control.\n'
#  'platform that aims to motivate users to make good financial choices and, in '
#  'turn, create a more \n'
#  'Cred is a FinT ech company that was founded in 2018 with a mission to '
#  'simplify the credit card \n'
#  'The platform aims to revolutionize how credit card users interact with their '
#  'finances by of fering \n'
#  'exclusive privileges and benefits to those with good credit scores, thereby '
#  'creating a flywheel \n'
#  'It is a platform that aims to reward creditworthy individuals while '
#  'addressing trust issues within \n'
#  "The company's mission is to create a platform that not only facilitates "
#  'credit card \n'
#  'bill payments but also of fers rewards for timely payments, thereby '
#  'encouraging financial \n'
#  'The idea was to of fer rewards to people who pay their credit card \n'
#  "Cred’ s unique approach as a 'T rustT ech' platform, rather than just "
#  "'Fintech', reflects Shah's belief \n"
#  'company aims to build trust between borrowers and lenders, by providing a '
#  'platform that \n'
#  'rewards creditworthy individuals and incentivizes financial responsibility '
#  '.\n'
#  'Cred is a members-only credit card bill payment platform that rewards its '
#  'members for clearing \n'
#  'Cred members get access to exclusive rewards and experiences \n'
#  'from premier brands upon clearing their credit card bills on cred.\n'
#  'and services designed to enhance the credit card payment experience.\n'
#  'customers to lend and borrow money from one another using the Cred app.\n'
#  'pre-approved credit lines of up to Rs 5 lakhs to Cred members without any \n'
#  '●  Rent Pay  : Launched in April 2020, Rent Pay enables  Cred users to pay '
#  'their monthly \n'
#  '●  Utility Bill Payments  : Launched in April 2022, this  feature allows '
#  'their users to pay \n'
#  '●  P2P Payments  : Launched in April 2023, this feature  allows their '
#  'customers to send \n'
#  'NPCI, this feature enables customers to make UPI payments using their credit '
#  'cards.\n'
#  'Cred’ s main tar get audience is credit card users in India who make up only '
#  '1% of the wealthiest \n'
#  'Cred, a leading fintech company , has established an impressive and diverse '
#  'group of partners and \n'
#  'Among the institutional investors who have supported Cred are Ribbit '
#  'Capital, Peak \n'
#  '●  Cred App:  It offers easy sign-up and attractive credit card bill of '
#  'fers.\n'
#  '●  Businesses that pr ovide offers on the app:  Cred of fers its users many '
#  'exclusive deals \n'
#  'T o do this, cred partners with businesses to provide its \n'
#  '●  Users who pay cr edit card bills:  Cred is a simple and user -friendly '
#  'platform for paying \n'
#  'cred provides you with a smooth payment experience and exclusive \n'
#  '●  Cred Mint:  Cred, a lending platform, on Aug 20, 2021,  launched a new '
#  'feature called \n'
#  'This feature allows cred users to lend their unused money to other '
#  'trustworthy \n'
#  '●  Google Pay  is a digital payment platform created by  Google, which is a '
#  'competitor of \n'
#  '●  Amazon Pay  , launched in 2007 by Amazon, is a rival  to cred, which now '
#  'of fers diverse \n'
#  '●  MobiKwik,  a Gurugram-based fintech company founded  in 2009, is a rival '
#  'of cred that \n'
#  '●  Cred and  Freecharge  are two companies that of fer mobile and utility '
#  'bill payment \n'
#  'Cred is a financial services company that focuses on fintech solutions.\n'
#  'products designed for credit card users, including rewards for timely '
#  'payments and other \n'
#  'which provides exclusive travel experiences for high-credit-score users.\n'
#  '●  Data Security:  Cred prioritizes user data protection, ensuring a safe '
#  'and secure platform.\n'
#  '●  Diverse Pr oduct Offerings:  From credit card payments to cred RentPay '
#  'and Cred Cash, \n'
#  'the company provides a wide range of financial services.\n'
#  '●  Rewards for Cr editworthiness  : It rewards users for  timely credit card '
#  'bill payments, \n'
#  '●  Exclusive Membership  : Cred is accessible only to individuals  with a '
#  'credit score above \n'
#  '●  Diverse Financial Services  : Beyond credit card payments,  Cred of fers '
#  'services like \n'
#  'Cred is a financial technology company that is committed to helping people '
#  'manage their \n'
#  '●  Simplifying credit card payments \n'
#  'Firstly , Cred aims to incentivize good credit behavior by rewarding '
#  'individuals who exhibit \n'
#  'The company of fers rewards and benefits to users who maintain good \n'
#  'This approach helps  users not only improve their credit scores but also '
#  'develop good financial habits that will benefit \n'
#  'Secondly , Cred simplifies credit card payments by providing a single '
#  'platform that allows users \n'
#  'to manage all their credit card payments in one place.\n'
#  'Finally , Cred promotes financial responsibility by encouraging users to '
#  'make informed financial \n'
#  "Overall, Cred's mission is to build a community where trust in financial "
#  'transactions is superior \n'
#  'By incentivizing good credit behavior , simplifying credit card payments, '
#  'and \n'
#  'promoting financial responsibility , Cred is helping users take control of '
#  'their finances and create \n'
#  'CRED, like any fintech company , faces several risks.\n'
#  '●  Additionally , as a fintech platform, Cred is exposed to credit risks '
#  'such as default risk, \n'
#  'Cred has been expanding its services, including the establishment of an '
#  'e-commerce platform, \n'
#  'CRED, operating in the dynamic fintech sector , faces VUCA challenges that '
#  'are common to \n'
#  'The journey of Cred of fers several valuable lessons for businesses and '
#  'entrepreneurs: ')

# %%
print(summarize(fulltext, split=True))
# Out:
# ['simplify credit card management and improve financial control.',
#  'platform that aims to motivate users to make good financial choices and, in '
#  'turn, create a more ',
#  'Cred is a FinT ech company that was founded in 2018 with a mission to '
#  'simplify the credit card ',
#  'The platform aims to revolutionize how credit card users interact with their '
#  'finances by of fering ',
#  'exclusive privileges and benefits to those with good credit scores, thereby '
#  'creating a flywheel ',
#  'It is a platform that aims to reward creditworthy individuals while '
#  'addressing trust issues within ',
#  "The company's mission is to create a platform that not only facilitates "
#  'credit card ',
#  'bill payments but also of fers rewards for timely payments, thereby '
#  'encouraging financial ',
#  'The idea was to of fer rewards to people who pay their credit card ',
#  "Cred’ s unique approach as a 'T rustT ech' platform, rather than just "
#  "'Fintech', reflects Shah's belief ",
#  'company aims to build trust between borrowers and lenders, by providing a '
#  'platform that ',
#  'rewards creditworthy individuals and incentivizes financial responsibility .',
#  'Cred is a members-only credit card bill payment platform that rewards its '
#  'members for clearing ',
#  'Cred members get access to exclusive rewards and experiences ',
#  'from premier brands upon clearing their credit card bills on cred.',
#  'and services designed to enhance the credit card payment experience.',
#  'customers to lend and borrow money from one another using the Cred app.',
#  'pre-approved credit lines of up to Rs 5 lakhs to Cred members without any ',
#  '●  Rent Pay  : Launched in April 2020, Rent Pay enables  Cred users to pay '
#  'their monthly ',
#  '●  Utility Bill Payments  : Launched in April 2022, this  feature allows '
#  'their users to pay ',
#  '●  P2P Payments  : Launched in April 2023, this feature  allows their '
#  'customers to send ',
#  'NPCI, this feature enables customers to make UPI payments using their credit '
#  'cards.',
#  'Cred’ s main tar get audience is credit card users in India who make up only '
#  '1% of the wealthiest ',
#  'Cred, a leading fintech company , has established an impressive and diverse '
#  'group of partners and ',
#  'Among the institutional investors who have supported Cred are Ribbit '
#  'Capital, Peak ',
#  '●  Cred App:  It offers easy sign-up and attractive credit card bill of '
#  'fers.',
#  '●  Businesses that pr ovide offers on the app:  Cred of fers its users many '
#  'exclusive deals ',
#  'T o do this, cred partners with businesses to provide its ',
#  '●  Users who pay cr edit card bills:  Cred is a simple and user -friendly '
#  'platform for paying ',
#  'cred provides you with a smooth payment experience and exclusive ',
#  '●  Cred Mint:  Cred, a lending platform, on Aug 20, 2021,  launched a new '
#  'feature called ',
#  'This feature allows cred users to lend their unused money to other '
#  'trustworthy ',
#  '●  Google Pay  is a digital payment platform created by  Google, which is a '
#  'competitor of ',
#  '●  Amazon Pay  , launched in 2007 by Amazon, is a rival  to cred, which now '
#  'of fers diverse ',
#  '●  MobiKwik,  a Gurugram-based fintech company founded  in 2009, is a rival '
#  'of cred that ',
#  '●  Cred and  Freecharge  are two companies that of fer mobile and utility '
#  'bill payment ',
#  'Cred is a financial services company that focuses on fintech solutions.',
#  'products designed for credit card users, including rewards for timely '
#  'payments and other ',
#  'which provides exclusive travel experiences for high-credit-score users.',
#  '●  Data Security:  Cred prioritizes user data protection, ensuring a safe '
#  'and secure platform.',
#  '●  Diverse Pr oduct Offerings:  From credit card payments to cred RentPay '
#  'and Cred Cash, ',
#  'the company provides a wide range of financial services.',
#  '●  Rewards for Cr editworthiness  : It rewards users for  timely credit card '
#  'bill payments, ',
#  '●  Exclusive Membership  : Cred is accessible only to individuals  with a '
#  'credit score above ',
#  '●  Diverse Financial Services  : Beyond credit card payments,  Cred of fers '
#  'services like ',
#  'Cred is a financial technology company that is committed to helping people '
#  'manage their ',
#  '●  Simplifying credit card payments ',
#  'Firstly , Cred aims to incentivize good credit behavior by rewarding '
#  'individuals who exhibit ',
#  'The company of fers rewards and benefits to users who maintain good ',
#  'This approach helps  users not only improve their credit scores but also '
#  'develop good financial habits that will benefit ',
#  'Secondly , Cred simplifies credit card payments by providing a single '
#  'platform that allows users ',
#  'to manage all their credit card payments in one place.',
#  'Finally , Cred promotes financial responsibility by encouraging users to '
#  'make informed financial ',
#  "Overall, Cred's mission is to build a community where trust in financial "
#  'transactions is superior ',
#  'By incentivizing good credit behavior , simplifying credit card payments, '
#  'and ',
#  'promoting financial responsibility , Cred is helping users take control of '
#  'their finances and create ',
#  'CRED, like any fintech company , faces several risks.',
#  '●  Additionally , as a fintech platform, Cred is exposed to credit risks '
#  'such as default risk, ',
#  'Cred has been expanding its services, including the establishment of an '
#  'e-commerce platform, ',
#  'CRED, operating in the dynamic fintech sector , faces VUCA challenges that '
#  'are common to ',
#  'The journey of Cred of fers several valuable lessons for businesses and '
#  'entrepreneurs: ']

# %%
print(summarize(fulltext, ratio=0.1, split=True))
# Out:
# ['simplify credit card management and improve financial control.',
#  'platform that aims to motivate users to make good financial choices and, in '
#  'turn, create a more ',
#  'Cred is a FinT ech company that was founded in 2018 with a mission to '
#  'simplify the credit card ',
#  'The platform aims to revolutionize how credit card users interact with their '
#  'finances by of fering ',
#  "The company's mission is to create a platform that not only facilitates "
#  'credit card ',
#  'The idea was to of fer rewards to people who pay their credit card ',
#  'Cred is a members-only credit card bill payment platform that rewards its '
#  'members for clearing ',
#  'from premier brands upon clearing their credit card bills on cred.',
#  'and services designed to enhance the credit card payment experience.',
#  '●  Utility Bill Payments  : Launched in April 2022, this  feature allows '
#  'their users to pay ',
#  'NPCI, this feature enables customers to make UPI payments using their credit '
#  'cards.',
#  'Cred’ s main tar get audience is credit card users in India who make up only '
#  '1% of the wealthiest ',
#  'Cred, a leading fintech company , has established an impressive and diverse '
#  'group of partners and ',
#  '●  Cred App:  It offers easy sign-up and attractive credit card bill of '
#  'fers.',
#  '●  Businesses that pr ovide offers on the app:  Cred of fers its users many '
#  'exclusive deals ',
#  '●  Cred and  Freecharge  are two companies that of fer mobile and utility '
#  'bill payment ',
#  'Cred is a financial services company that focuses on fintech solutions.',
#  'products designed for credit card users, including rewards for timely '
#  'payments and other ',
#  'which provides exclusive travel experiences for high-credit-score users.',
#  '●  Rewards for Cr editworthiness  : It rewards users for  timely credit card '
#  'bill payments, ',
#  '●  Diverse Financial Services  : Beyond credit card payments,  Cred of fers '
#  'services like ',
#  'Cred is a financial technology company that is committed to helping people '
#  'manage their ',
#  'Firstly , Cred aims to incentivize good credit behavior by rewarding '
#  'individuals who exhibit ',
#  'The company of fers rewards and benefits to users who maintain good ',
#  'This approach helps  users not only improve their credit scores but also '
#  'develop good financial habits that will benefit ',
#  'Secondly , Cred simplifies credit card payments by providing a single '
#  'platform that allows users ',
#  'to manage all their credit card payments in one place.',
#  'promoting financial responsibility , Cred is helping users take control of '
#  'their finances and create ',
#  'CRED, like any fintech company , faces several risks.',
#  '●  Additionally , as a fintech platform, Cred is exposed to credit risks '
#  'such as default risk, ']

# %%
print(summarize(fulltext, word_count=150))
# Out:
# ('Cred is a FinT ech company that was founded in 2018 with a mission to '
#  'simplify the credit card \n'
#  "The company's mission is to create a platform that not only facilitates "
#  'credit card \n'
#  'Cred is a members-only credit card bill payment platform that rewards its '
#  'members for clearing \n'
#  '●  Cred App:  It offers easy sign-up and attractive credit card bill of '
#  'fers.\n'
#  '●  Businesses that pr ovide offers on the app:  Cred of fers its users many '
#  'exclusive deals \n'
#  'Cred is a financial services company that focuses on fintech solutions.\n'
#  'products designed for credit card users, including rewards for timely '
#  'payments and other \n'
#  '●  Diverse Financial Services  : Beyond credit card payments,  Cred of fers '
#  'services like \n'
#  'Secondly , Cred simplifies credit card payments by providing a single '
#  'platform that allows users \n'
#  'promoting financial responsibility , Cred is helping users take control of '
#  'their finances and create ')

# %%
print(keywords(fulltext))
# Out:
# ('cred\n'
#  'users\n'
#  'user\n'
#  'credit\n'
#  'credits\n'
#  'payments\n'
#  'payment\n'
#  'marketing\n'
#  'market\n'
#  'platform\n'
#  'financially responsible\n'
#  'include\n'
#  'including\n'
#  'data\n'
#  'customer service\n'
#  'fintech\n'
#  'capital\n'
#  'risk\n'
#  'risks\n'
#  'faced financial dif\n'
#  'rewarding\n'
#  'services\n'
#  'exclusive\n'
#  'includes offering\n'
#  'innovation\n'
#  'innovative\n'
#  'cards\n'
#  'card\n'
#  'companies\n'
#  'base\n'
#  'banking\n'
#  'bank\n'
#  'allows customers\n'
#  'business\n'
#  'businesses\n'
#  'launched\n'
#  'security\n'
#  'secure\n'
#  'fers rewards\n'
#  'management\n'
#  'manage\n'
#  'ech company\n'
#  'trust\n'
#  'consumer\n'
#  'consumers\n'
#  'pay\n'
#  'paying\n'
#  'offers\n'
#  'offerings\n'
#  'investors\n'
#  'investor\n'
#  'reward creditworthy individuals\n'
#  'economic\n'
#  'making\n'
#  'money\n'
#  'feature\n'
#  'featur\n'
#  'individual\n'
#  'strong\n'
#  'strategy\n'
#  'strategies\n'
#  'features uniqueness\n'
#  'providing\n'
#  'provides\n'
#  'provide\n'
#  'unique\n'
#  'strategic\n'
#  'calls\n'
#  'called\n'
#  'brands\n'
#  'brand\n'
#  'finances\n'
#  'finance\n'
#  'faces\n'
#  'face\n'
#  'fer\n'
#  'good\n'
#  'key\n'
#  'worked\n'
#  'working\n'
#  'works\n'
#  'app\n'
#  'apps\n'
#  'indians\n'
#  'behavior\n'
#  'allow\n'
#  'private\n'
#  'shah\n'
#  'sector\n'
#  'diverse\n'
#  'global\n'
#  'new\n'
#  'low\n'
#  'timely\n'
#  'time\n'
#  'significant\n'
#  'edge\n'
#  'creditworthiness\n'
#  'scores\n'
#  'score\n'
#  'institute\n'
#  'institutional\n'
#  'park\n'
#  'wealth\n'
#  'indian entrepreneur\n'
#  'model\n'
#  'technology\n'
#  'technological\n'
#  'bills\n'
#  'responsibility\n'
#  'responsibly\n'
#  'ones\n'
#  'incentivizing\n'
#  'incentivizes\n'
#  'incentivization\n'
#  'incentivize\n'
#  'rent\n'
#  'vuca\n'
#  'growth\n'
#  'enables\n'
#  'small\n'
#  'utility\n'
#  'utilization\n'
#  'premium\n'
#  'option\n'
#  'options\n'
#  'lar\n'
#  'regular\n'
#  'study\n'
#  'studies\n'
#  'travel\n'
#  'partner\n'
#  'partners\n'
#  'partnered\n'
#  'entrepreneurs\n'
#  'vertical\n'
#  'loan\n'
#  'loans\n'
#  'india\n'
#  'uttar\n'
#  'aur\n'
#  'bhar osa\n'
#  'valuable experience\n'
#  'pradesh\n'
#  'government\n'
#  'governments\n'
#  'changes\n'
#  'changing\n'
#  'better\n'
#  'kunal\n'
#  'process\n'
#  'processed\n'
#  'focuses\n'
#  'focusing\n'
#  'focused\n'
#  'experiences')

# %%
print(keywords(fulltext, lemmatize=True))
# Out:
# ('cred\n'
#  'financially\n'
#  'user\n'
#  'credits\n'
#  'payment\n'
#  'market\n'
#  'platform\n'
#  'data\n'
#  'customer service\n'
#  'fintech\n'
#  'risks\n'
#  'rewarding\n'
#  'exclusive\n'
#  'includes offering\n'
#  'innovative\n'
#  'card\n'
#  'companies\n'
#  'base\n'
#  'bank\n'
#  'businesses\n'
#  'launched\n'
#  'secure\n'
#  'manage\n'
#  'trust\n'
#  'consumers\n'
#  'paying\n'
#  'investor\n'
#  'economic\n'
#  'ech\n'
#  'making\n'
#  'money\n'
#  'individual\n'
#  'strong\n'
#  'strategies\n'
#  'features uniqueness\n'
#  'provide\n'
#  'strategic\n'
#  'called\n'
#  'brand\n'
#  'finance\n'
#  'face\n'
#  'fer\n'
#  'good\n'
#  'key\n'
#  'works\n'
#  'apps\n'
#  'indians\n'
#  'behavior\n'
#  'allow\n'
#  'private\n'
#  'shah\n'
#  'sector\n'
#  'diverse\n'
#  'global\n'
#  'new\n'
#  'low\n'
#  'timely\n'
#  'significant\n'
#  'edge\n'
#  'creditworthiness\n'
#  'score\n'
#  'institutional\n'
#  'park\n'
#  'wealth\n'
#  'model\n'
#  'technological\n'
#  'bills\n'
#  'responsibly\n'
#  'ones\n'
#  'incentivize\n'
#  'rent\n'
#  'vuca\n'
#  'growth\n'
#  'enables\n'
#  'small\n'
#  'utilization\n'
#  'dif\n'
#  'premium\n'
#  'options\n'
#  'lar\n'
#  'regular\n'
#  'valuable\n'
#  'studies\n'
#  'travel\n'
#  'partnered\n'
#  'entrepreneurs\n'
#  'vertical\n'
#  'loans\n'
#  'india\n'
#  'uttar\n'
#  'aur\n'
#  'bhar osa\n'
#  'pradesh\n'
#  'governments\n'
#  'changing\n'
#  'better\n'
#  'kunal\n'
#  'processed\n'
#  'focused\n'
#  'experiences')

# %%
print(keywords(fulltext, split=True))
# Out:
# ['cred',
#  'users',
#  'user',
#  'credit',
#  'credits',
#  'payments',
#  'payment',
#  'marketing',
#  'market',
#  'platform',
#  'financially responsible',
#  'include',
#  'including',
#  'data',
#  'customer service',
#  'fintech',
#  'capital',
#  'risk',
#  'risks',
#  'faced financial dif',
#  'rewarding',
#  'services',
#  'exclusive',
#  'includes offering',
#  'innovation',
#  'innovative',
#  'cards',
#  'card',
#  'companies',
#  'base',
#  'banking',
#  'bank',
#  'allows customers',
#  'business',
#  'businesses',
#  'launched',
#  'security',
#  'secure',
#  'fers rewards',
#  'management',
#  'manage',
#  'ech company',
#  'trust',
#  'consumer',
#  'consumers',
#  'pay',
#  'paying',
#  'offers',
#  'offerings',
#  'investors',
#  'investor',
#  'reward creditworthy individuals',
#  'economic',
#  'making',
#  'money',
#  'feature',
#  'featur',
#  'individual',
#  'strong',
#  'strategy',
#  'strategies',
#  'features uniqueness',
#  'providing',
#  'provides',
#  'provide',
#  'unique',
#  'strategic',
#  'calls',
#  'called',
#  'brands',
#  'brand',
#  'finances',
#  'finance',
#  'faces',
#  'face',
#  'fer',
#  'good',
#  'key',
#  'worked',
#  'working',
#  'works',
#  'app',
#  'apps',
#  'indians',
#  'behavior',
#  'allow',
#  'private',
#  'shah',
#  'sector',
#  'diverse',
#  'global',
#  'new',
#  'low',
#  'timely',
#  'time',
#  'significant',
#  'edge',
#  'creditworthiness',
#  'scores',
#  'score',
#  'institute',
#  'institutional',
#  'wealth',
#  'park',
#  'indian entrepreneur',
#  'model',
#  'technology',
#  'technological',
#  'bills',
#  'responsibility',
#  'responsibly',
#  'ones',
#  'incentivizing',
#  'incentivizes',
#  'incentivization',
#  'incentivize',
#  'rent',
#  'vuca',
#  'growth',
#  'enables',
#  'small',
#  'utility',
#  'utilization',
#  'premium',
#  'option',
#  'options',
#  'lar',
#  'regular',
#  'study',
#  'studies',
#  'travel',
#  'partner',
#  'partners',
#  'partnered',
#  'entrepreneurs',
#  'vertical',
#  'loan',
#  'loans',
#  'india',
#  'uttar',
#  'aur',
#  'bhar osa',
#  'valuable experience',
#  'pradesh',
#  'government',
#  'governments',
#  'changes',
#  'changing',
#  'better',
#  'kunal',
#  'process',
#  'processed',
#  'focuses',
#  'focusing',
#  'focused',
#  'experiences']

# %%
print(keywords(fulltext, ratio=0.1))
# Out:
# ('cred\n'
#  'financially\n'
#  'users\n'
#  'user\n'
#  'credit\n'
#  'credits\n'
#  'payments\n'
#  'payment\n'
#  'marketing\n'
#  'market\n'
#  'platform\n'
#  'faced financial\n'
#  'include\n'
#  'including\n'
#  'customers\n'
#  'data\n'
#  'customer service\n'
#  'fintech\n'
#  'capital\n'
#  'risk\n'
#  'risks\n'
#  'reward\n'
#  'rewarding\n'
#  'services\n'
#  'exclusive\n'
#  'includes offering\n'
#  'innovation\n'
#  'innovative\n'
#  'cards\n'
#  'card\n'
#  'companies\n'
#  'base\n'
#  'banking\n'
#  'bank\n'
#  'business\n'
#  'businesses\n'
#  'launched\n'
#  'security\n'
#  'secure\n'
#  'fers rewards\n'
#  'management\n'
#  'manage\n'
#  'ech company\n'
#  'trust\n'
#  'consumer\n'
#  'consumers\n'
#  'pay\n'
#  'paying\n'
#  'offers\n'
#  'offerings\n'
#  'investors\n'
#  'investor\n'
#  'economic\n'
#  'making\n'
#  'money\n'
#  'feature\n'
#  'featur\n'
#  'individuals\n'
#  'individual\n'
#  'strong\n'
#  'strategy\n'
#  'strategies\n'
#  'features uniqueness\n'
#  'providing\n'
#  'provides\n'
#  'provide\n'
#  'unique\n'
#  'strategic\n'
#  'calls\n'
#  'called\n'
#  'brands\n'
#  'brand\n'
#  'finances\n'
#  'finance\n'
#  'faces\n'
#  'face\n'
#  'fer\n'
#  'good\n'
#  'key\n'
#  'worked\n'
#  'working\n'
#  'works\n'
#  'app\n'
#  'apps\n'
#  'indian\n'
#  'indians\n'
#  'behavior')
